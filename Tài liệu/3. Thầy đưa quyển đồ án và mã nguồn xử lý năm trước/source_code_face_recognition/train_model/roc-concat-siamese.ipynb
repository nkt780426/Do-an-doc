# %%
# !git clone https://github.com/hoangngoclam298/Siamese-Triplet-Model.git
# Out:
# Cloning into 'Siamese-Triplet-Model'...
# remote: Enumerating objects: 89, done.
# remote: Counting objects: 100% (89/89), done.
# remote: Compressing objects: 100% (74/74), done.
# remote: Total 89 (delta 30), reused 73 (delta 14), pack-reused 0
# Unpacking objects: 100% (89/89), 4.05 MiB | 12.09 MiB/s, done.

# %%
# %cd /kaggle/working/Siamese-Triplet-Model
# Out:
# /kaggle/working/Siamese-Triplet-Model

# %%
from torchvision import datasets, transforms
import numpy as np
from PIL import Image
import torch.nn as nn
import torch.nn.functional as F
import os
from torch.utils.data import Dataset, DataLoader
import random
import torch
import shutil
import time
from torch.optim import lr_scheduler
import torch.optim as optim
from networks import *
from datasets import *
from losses import *
from metrics import *
# from trainer import *
import warnings

warnings.filterwarnings("ignore", category=UserWarning)

# %%
path_root = '/kaggle/input/new-data-face/data_train_2d_new/data_train_2d'
new_path_train = '/kaggle/working/data_train_2d'
new_path_test = '/kaggle/working/data_test_2d'

if os.path.exists(new_path_train):
    shutil.rmtree(new_path_train)
os.makedirs(new_path_train, exist_ok=True)

if os.path.exists(new_path_test):
    shutil.rmtree(new_path_test)
os.makedirs(new_path_test, exist_ok=True)

list_id = os.listdir(path_root)
random.shuffle(list_id)
list_train = ['1038', '1190', '1187', '1041', '2175', '1134', '2059', '1220', '1119', '2198', '2005', '1031', '1008', '1042', '1221', '1080', '2170', '1032', '2029', '2046', '1075', '2017', '1012', '2213', '2023', '2002', '2072', '2197', '1089', '2183', '1027', '1189', '2215', '2200', '2191', '2214', '1186', '2193', '1182', '1002', '2223', '1050', '1188', '1133', '1200', '2075', '1151', '1116', '2006', '2207', '1022', '1208', '1024', '1199', '1088', '2177', '2009', '2185', '1195', '1213', '2051', '2021', '1099', '2052', '2019', '2218', '2205', '2226', '1013', '2173', '1003', '1144', '1175', '1085', '1196', '2209', '1074', '2068', '2188', '2195', '2086', '2016', '1039', '1217', '2011', '2186', '1037', '1181', '1173', '2203', '1066', '1004', '2180', '2008', '1201', '1197', '1192', '2201', '1174', '1184', '2060', '2064', '2181', '2012']
list_test = ['2172', '1040', '2189', '2174', '2184', '1043', '2219', '2179', '2225', '1072', '2210', '2074', '1001', '2001', '1014', '2176', '1177', '2141', '2004', '1067', '2211', '2054', '2178', '1047', '2190', '1025', '1009']

for id in list_train:
    path_id = os.path.join(path_root, id)
    list_id_image = [x for x in os.listdir(path_id) if x.endswith('.png')]
    if len(list_id_image) > 1:
        if len(list_id_image) > 5:
            list_id_image = random.sample(list_id_image, 5)
        os.makedirs(os.path.join(new_path_train, id), exist_ok=True)
        for id_image in list_id_image:
            source_file = os.path.join(path_id, id_image)
            destination_file = os.path.join(new_path_train, id, id_image)
            shutil.copy(source_file, destination_file)

for id in list_test:
    path_id = os.path.join(path_root, id)
    list_id_image = [x for x in os.listdir(path_id) if x.endswith('.png')]
    if len(list_id_image) > 1:
        if len(list_id_image) > 5:
            list_id_image = random.sample(list_id_image, 5)
        os.makedirs(os.path.join(new_path_test, id), exist_ok=True)
        for id_image in list_id_image:
            source_file = os.path.join(path_id, id_image)
            destination_file = os.path.join(new_path_test, id, id_image)
            shutil.copy(source_file, destination_file)
            

            
path_root = '/kaggle/input/new-data-face/data_train_3d_new/data_train_3d'
new_path_train = '/kaggle/working/data_train_3d'
new_path_test = '/kaggle/working/data_test_3d'

if os.path.exists(new_path_train):
    shutil.rmtree(new_path_train)
os.makedirs(new_path_train, exist_ok=True)

if os.path.exists(new_path_test):
    shutil.rmtree(new_path_test)
os.makedirs(new_path_test, exist_ok=True)

list_id = os.listdir(path_root)
random.shuffle(list_id)
list_train = ['1038', '1190', '1187', '1041', '2175', '1134', '2059', '1220', '1119', '2198', '2005', '1031', '1008', '1042', '1221', '1080', '2170', '1032', '2029', '2046', '1075', '2017', '1012', '2213', '2023', '2002', '2072', '2197', '1089', '2183', '1027', '1189', '2215', '2200', '2191', '2214', '1186', '2193', '1182', '1002', '2223', '1050', '1188', '1133', '1200', '2075', '1151', '1116', '2006', '2207', '1022', '1208', '1024', '1199', '1088', '2177', '2009', '2185', '1195', '1213', '2051', '2021', '1099', '2052', '2019', '2218', '2205', '2226', '1013', '2173', '1003', '1144', '1175', '1085', '1196', '2209', '1074', '2068', '2188', '2195', '2086', '2016', '1039', '1217', '2011', '2186', '1037', '1181', '1173', '2203', '1066', '1004', '2180', '2008', '1201', '1197', '1192', '2201', '1174', '1184', '2060', '2064', '2181', '2012']
list_test = ['2172', '1040', '2189', '2174', '2184', '1043', '2219', '2179', '2225', '1072', '2210', '2074', '1001', '2001', '1014', '2176', '1177', '2141', '2004', '1067', '2211', '2054', '2178', '1047', '2190', '1025', '1009']

for id in list_train:
    path_id = os.path.join(path_root, id)
    list_id_image = [x for x in os.listdir(path_id) if x.endswith('.png')]
    if len(list_id_image) > 1:
        if len(list_id_image) > 5:
            list_id_image = random.sample(list_id_image, 5)
        os.makedirs(os.path.join(new_path_train, id), exist_ok=True)
        for id_image in list_id_image:
            source_file = os.path.join(path_id, id_image)
            destination_file = os.path.join(new_path_train, id, id_image)
            shutil.copy(source_file, destination_file)

for id in list_test:
    path_id = os.path.join(path_root, id)
    list_id_image = [x for x in os.listdir(path_id) if x.endswith('.png')]
    if len(list_id_image) > 1:
        if len(list_id_image) > 5:
            list_id_image = random.sample(list_id_image, 5)
        os.makedirs(os.path.join(new_path_test, id), exist_ok=True)
        for id_image in list_id_image:
            source_file = os.path.join(path_id, id_image)
            destination_file = os.path.join(new_path_test, id, id_image)
            shutil.copy(source_file, destination_file)

# %%
import os
from PIL import Image
import torch
from torch.utils.data import Dataset
from torchvision import transforms

class ConcatDataset(Dataset):
    def __init__(self, data_dir1, data_dir2, transform=None):
        self.data_dir1 = data_dir1
        self.data_dir2 = data_dir2
        self.transform = transform
        self.classes = sorted(os.listdir(os.path.join(data_dir1)))
        self.class_to_idx = {cls: i for i, cls in enumerate(self.classes)}
        self.img_paths = self._get_img_paths()

    def _get_img_paths(self):
        img_paths = []
        for cls in self.classes:
            cls_dir1 = os.path.join(self.data_dir1, cls)
            cls_dir2 = os.path.join(self.data_dir2, cls)
            for img_name in os.listdir(cls_dir1):
                img_path1 = os.path.join(cls_dir1, img_name)
                img_path2 = os.path.join(cls_dir2, img_name)
                img_paths.append((img_path1, img_path2, self.class_to_idx[cls]))
        return img_paths

    def __len__(self):
        return len(self.img_paths)

    def __getitem__(self, idx):
        img_path1, img_path2, label = self.img_paths[idx]
        img1 = Image.open(img_path1).convert("RGB")
        img2 = Image.open(img_path2).convert("RGB")

        if self.transform:
            img1 = self.transform(img1)
            img2 = self.transform(img2)

        return img1, img2, label

# %%
cuda = torch.cuda.is_available()

trans_train = transforms.Compose([
#     transforms.RandomRotation(degrees=(-15, 15)),
    RandomResizedCropRect(size=(256, 256)),
    GaussianNoise(),
    np.float32,
    transforms.ToTensor(),
    fixed_image_standardization
])

trans_val = transforms.Compose([
#     transforms.RandomRotation(degrees=(-15, 15)),
    transforms.Resize((256, 256)),
    np.float32,
    transforms.ToTensor(),
    fixed_image_standardization
])

new_path_train1 = '/kaggle/working/data_train_2d'
new_path_test1 = '/kaggle/working/data_test_2d'
new_path_train2 = '/kaggle/working/data_train_3d'
new_path_test2 = '/kaggle/working/data_test_3d'

train_dataset = SiameseDatasetConcat(data_dir1=new_path_train1, data_dir2=new_path_train2, transform=trans_train, train=True)
test_dataset = SiameseDatasetConcat(data_dir1=new_path_test1, data_dir2=new_path_test2, transform=trans_val, train=False)

batch_size = 8
kwargs = {'num_workers': 1, 'pin_memory': True} if cuda else {}
siamese_train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True, **kwargs)
siamese_test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False, **kwargs)

workers = 0 if os.name == 'nt' else 8

train_dataset_image = ConcatDataset(data_dir1=new_path_train1, data_dir2=new_path_train2, transform=trans_train)
train_loader_image = DataLoader(
    train_dataset_image,
    num_workers=workers,
    batch_size=batch_size,
)

val_dataset_image = ConcatDataset(data_dir1=new_path_test1, data_dir2=new_path_test2, transform=trans_val)
val_loader_image = DataLoader(
    val_dataset_image,
    num_workers=workers,
    batch_size=batch_size,
)

# %%
import torch
import numpy as np
from tqdm import tqdm
from sklearn.metrics import roc_curve, auc
import torch.nn.functional as F


def fit(train_loader, val_loader, model, loss_fn, optimizer, scheduler, n_epochs, cuda, log_interval, metrics=[],
        start_epoch=0, save_best_loss=False, path_save='', num_epoch_roc = -1, train_loader_image=None, val_loader_image=None):
    """
    Loaders, model, loss function and metrics should work together for a given task,
    i.e. The model should be able to process data output of loaders,
    loss function should process target output of loaders and outputs from the model

    Examples: Classification: batch loader, classification model, NLL loss, accuracy metric
    Siamese network: Siamese loader, siamese model, contrastive loss
    Online triplet learning: batch loader, embedding model, online triplet loss
    """
    best_loss = 1000
    best_model = None

    for epoch in range(0, start_epoch):
        scheduler.step()

    for epoch in range(start_epoch, n_epochs):
        scheduler.step()

        # Train stage
        train_loss, metrics = train_epoch(train_loader, model, loss_fn, optimizer, cuda, log_interval, metrics)

        message = 'Epoch: {}/{}. Train set: Average loss: {:.4f}'.format(epoch + 1, n_epochs, train_loss)
        for metric in metrics:
            message += '\t{}: {}'.format(metric.name(), metric.value())

        val_loss, metrics = test_epoch(val_loader, model, loss_fn, cuda, metrics)
        val_loss /= len(val_loader)
        if save_best_loss:
            if val_loss < best_loss:
                best_loss = val_loss
                best_model = model.state_dict().copy()
        message += '\nEpoch: {}/{}. Validation set: Average loss: {:.4f}'.format(epoch + 1, n_epochs,
                                                                                 val_loss)
        for metric in metrics:
            message += '\t{}: {}'.format(metric.name(), metric.value())

        print(message)
        if num_epoch_roc != -1:
            if (epoch + 2) % num_epoch_roc == 0:
                roc_auc_dis, roc_auc_cos = check_ROC(train_loader_image, model, cuda)
                print('---Epoch: {}/{}. Train set: Distance ROC: {:.4f}\tCosine similarity ROC: {:.4f}'
                    .format(epoch + 1, n_epochs, roc_auc_dis, roc_auc_cos))
                roc_auc_dis, roc_auc_cos = check_ROC(val_loader_image, model, cuda)
                print('---Epoch: {}/{}. Validation set: Distance ROC: {:.4f}\tCosine similarity ROC: {:.4f}'
                    .format(epoch + 1, n_epochs, roc_auc_dis, roc_auc_cos))
    if save_best_loss:
        torch.save(best_model, path_save)


def train_epoch(train_loader, model, loss_fn, optimizer, cuda, log_interval, metrics):
    for metric in metrics:
        metric.reset()

    model.train()
    losses = []
    total_loss = 0

    for batch_idx, (data, target) in (enumerate(train_loader)):
        target = target if len(target) > 0 else None
        if not type(data) in (tuple, list):
            data = (data,)
        if cuda:
            data = tuple(d.cuda() for d in data)
            if target is not None:
                target = target.cuda()


        optimizer.zero_grad()
        outputs = model(*data)

        if type(outputs) not in (tuple, list):
            outputs = (outputs,)

        loss_inputs = outputs
        if target is not None:
            target = (target,)
            loss_inputs += target

        loss_outputs = loss_fn(*loss_inputs)
        loss = loss_outputs[0] if type(loss_outputs) in (tuple, list) else loss_outputs
        losses.append(loss.item())
        total_loss += loss.item()
        loss.backward()
        optimizer.step()

        for metric in metrics:
            metric(outputs, target, loss_outputs)

        # if batch_idx % log_interval == 0:
        #     message = 'Train: [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
        #         batch_idx * len(data[0]), len(train_loader.dataset),
        #         100. * batch_idx / len(train_loader), np.mean(losses))
        #     for metric in metrics:
        #         message += '\t{}: {}'.format(metric.name(), metric.value())

        #     print(message)
        #     losses = []

    total_loss /= (batch_idx + 1)
    return total_loss, metrics


def test_epoch(val_loader, model, loss_fn, cuda, metrics):
    with torch.no_grad():
        for metric in metrics:
            metric.reset()
        model.eval()
        val_loss = 0
        for batch_idx, (data, target) in enumerate(val_loader):
            target = target if len(target) > 0 else None
            if not type(data) in (tuple, list):
                data = (data,)
            if cuda:
                data = tuple(d.cuda() for d in data)
                if target is not None:
                    target = target.cuda()

            outputs = model(*data)

            if type(outputs) not in (tuple, list):
                outputs = (outputs,)
            loss_inputs = outputs
            if target is not None:
                target = (target,)
                loss_inputs += target

            loss_outputs = loss_fn(*loss_inputs)
            loss = loss_outputs[0] if type(loss_outputs) in (tuple, list) else loss_outputs
            val_loss += loss.item()

            for metric in metrics:
                metric(outputs, target, loss_outputs)

    return val_loss, metrics

def check_ROC(val_loader, model, device):
    with torch.no_grad():
        model.eval()
        outputs_list = []

        for batch in val_loader:
            image1, image2, ids = batch  # Giả sử batch trả về (ảnh, nhãn)
            image1 = image1.cuda()
            image2 = image2.cuda()
            outputs = model.get_embedding(image1, image2)
            
            for i in range(outputs.size(0)):
                outputs_list.append((ids[i].item(), outputs[i].cpu().numpy()))  # Lưu ID và output
        scores_dis = []
        labels_dis = []
        scores_cos = []
        labels_cos = []

        for i in range(len(outputs_list)):
            for j in range(i + 1, len(outputs_list)):
                id1, tensor1 = outputs_list[i]
                id2, tensor2 = outputs_list[j]

                # Chuyển đổi numpy array về tensor và chuyển lên thiết bị cuda
                tensor1 = torch.tensor(tensor1)
                tensor2 = torch.tensor(tensor2)

                # Tính khoảng cách Euclidean
                score_dis = F.pairwise_distance(tensor1, tensor2).item()
                # Tính cosine similarity
                score_cos = F.cosine_similarity(tensor1.unsqueeze(0), tensor2.unsqueeze(0)).item()

                # Lưu độ tương đồng và nhãn
                scores_dis.append(score_dis)
                labels_dis.append(0 if id1 == id2 else 1)
                scores_cos.append(score_cos)
                labels_cos.append(1 if id1 == id2 else 0)

        y_true_dis = np.array(labels_dis)
        y_scores_dis = np.array(scores_dis)
        fpr_dis, tpr_dis, thresholds_dis = roc_curve(y_true_dis, y_scores_dis)
        roc_auc_dis = auc(fpr_dis, tpr_dis)

        y_true_cos = np.array(labels_cos)
        y_scores_cos = np.array(scores_cos)
        fpr_cos, tpr_cos, thresholds_cos = roc_curve(y_true_cos, y_scores_cos)
        roc_auc_cos = auc(fpr_cos, tpr_cos)
    return roc_auc_dis, roc_auc_cos

# %%
margin = 1.
embedding_net = EmbeddingNet_Concat(num_classes = 1024)
model = SiameseNet_Concat(embedding_net)


model_path1 = r'/kaggle/input/weight-siamese/weight_2d_siamese.pt'
state_dict1 = torch.load(model_path1, map_location=torch.device('cuda'))
new_state_dict1 = {k[14:]: v for k, v in state_dict1.items()}
model.embedding_net.resnet1.load_state_dict(new_state_dict1, strict=True)

model_path2 = r'/kaggle/input/weight-siamese/weight_3d_siamese.pt'
state_dict2 = torch.load(model_path2, map_location=torch.device('cuda'))
new_state_dict2 = {k[14:]: v for k, v in state_dict1.items()}
model.embedding_net.resnet2.load_state_dict(new_state_dict2, strict=False)

# # Đóng băng resnet1
# for param in model.embedding_net.parameters():
#     param.requires_grad = False

# # Đóng băng resnet2
# for param in model.embedding_net.parameters():
#     param.requires_grad = False

model.eval()

if cuda:
    model.cuda()
loss_fn = ContrastiveLoss(margin)
lr = 1e-5
optimizer = optim.Adam(model.parameters(), lr=lr)
scheduler = lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=50, T_mult=1, eta_min=1e-6)

n_epochs = 1000
log_interval = 1
ts = time.time()
fit(siamese_train_loader, siamese_test_loader, model, loss_fn, optimizer, scheduler, n_epochs, cuda, log_interval, save_best_loss=True, path_save='/kaggle/working/best_model.pt', num_epoch_roc=10, train_loader_image=train_loader_image, val_loader_image=val_loader_image)
print(time.time()-ts)
torch.save(model.state_dict(), '/kaggle/working/last_model.pt')
# Out:
# Epoch: 1/1000. Train set: Average loss: 13.3461
# Epoch: 1/1000. Validation set: Average loss: 6.0495
# Epoch: 2/1000. Train set: Average loss: 8.0270
# Epoch: 2/1000. Validation set: Average loss: 4.1336
# Epoch: 3/1000. Train set: Average loss: 4.8525
# Epoch: 3/1000. Validation set: Average loss: 2.6026
# Epoch: 4/1000. Train set: Average loss: 3.8524
# Epoch: 4/1000. Validation set: Average loss: 1.7314
# Epoch: 5/1000. Train set: Average loss: 2.5898
# Epoch: 5/1000. Validation set: Average loss: 1.3167
# Epoch: 6/1000. Train set: Average loss: 1.9468
# Epoch: 6/1000. Validation set: Average loss: 0.9983
# Epoch: 7/1000. Train set: Average loss: 1.4094
# Epoch: 7/1000. Validation set: Average loss: 0.7061
# Epoch: 8/1000. Train set: Average loss: 1.1122
# Epoch: 8/1000. Validation set: Average loss: 0.5857
# Epoch: 9/1000. Train set: Average loss: 0.8821
# Epoch: 9/1000. Validation set: Average loss: 0.5094
# ---Epoch: 9/1000. Train set: Distance ROC: 0.9780	Cosine similarity ROC: 0.9704
# ---Epoch: 9/1000. Validation set: Distance ROC: 0.9106	Cosine similarity ROC: 0.9188
# Epoch: 10/1000. Train set: Average loss: 0.7312
# Epoch: 10/1000. Validation set: Average loss: 0.4071
# Epoch: 11/1000. Train set: Average loss: 0.5815
# Epoch: 11/1000. Validation set: Average loss: 0.3441
# Epoch: 12/1000. Train set: Average loss: 0.4289
# Epoch: 12/1000. Validation set: Average loss: 0.2285
# Epoch: 13/1000. Train set: Average loss: 0.3469
# Epoch: 13/1000. Validation set: Average loss: 0.2217
# Epoch: 14/1000. Train set: Average loss: 0.3512
# Epoch: 14/1000. Validation set: Average loss: 0.1803
# Epoch: 15/1000. Train set: Average loss: 0.2817
# Epoch: 15/1000. Validation set: Average loss: 0.1410
# Epoch: 16/1000. Train set: Average loss: 0.2715
# Epoch: 16/1000. Validation set: Average loss: 0.1499
# Epoch: 17/1000. Train set: Average loss: 0.2160
# Epoch: 17/1000. Validation set: Average loss: 0.1093
# Epoch: 18/1000. Train set: Average loss: 0.2139
# Epoch: 18/1000. Validation set: Average loss: 0.1017
# Epoch: 19/1000. Train set: Average loss: 0.1727
# Epoch: 19/1000. Validation set: Average loss: 0.0852
# ---Epoch: 19/1000. Train set: Distance ROC: 0.9717	Cosine similarity ROC: 0.9705
# ---Epoch: 19/1000. Validation set: Distance ROC: 0.8995	Cosine similarity ROC: 0.9124
# Epoch: 20/1000. Train set: Average loss: 0.1677
# Epoch: 20/1000. Validation set: Average loss: 0.0900
# Epoch: 21/1000. Train set: Average loss: 0.1699
# Epoch: 21/1000. Validation set: Average loss: 0.0855
# Epoch: 22/1000. Train set: Average loss: 0.1349
# Epoch: 22/1000. Validation set: Average loss: 0.0680
# Epoch: 23/1000. Train set: Average loss: 0.1318
# Epoch: 23/1000. Validation set: Average loss: 0.0721
# Epoch: 24/1000. Train set: Average loss: 0.1261
# Epoch: 24/1000. Validation set: Average loss: 0.0632
# Epoch: 25/1000. Train set: Average loss: 0.1180
# Epoch: 25/1000. Validation set: Average loss: 0.0685
# Epoch: 26/1000. Train set: Average loss: 0.1070
# Epoch: 26/1000. Validation set: Average loss: 0.0619
# Epoch: 27/1000. Train set: Average loss: 0.0999
# Epoch: 27/1000. Validation set: Average loss: 0.0603
# Epoch: 28/1000. Train set: Average loss: 0.1135
# Epoch: 28/1000. Validation set: Average loss: 0.0618
# Epoch: 29/1000. Train set: Average loss: 0.1099
# Epoch: 29/1000. Validation set: Average loss: 0.0572
# ---Epoch: 29/1000. Train set: Distance ROC: 0.9705	Cosine similarity ROC: 0.9734
# ---Epoch: 29/1000. Validation set: Distance ROC: 0.8923	Cosine similarity ROC: 0.9038
# Epoch: 30/1000. Train set: Average loss: 0.0943
# Epoch: 30/1000. Validation set: Average loss: 0.0554
# Epoch: 31/1000. Train set: Average loss: 0.0955
# Epoch: 31/1000. Validation set: Average loss: 0.0578
# Epoch: 32/1000. Train set: Average loss: 0.0978
# Epoch: 32/1000. Validation set: Average loss: 0.0590
# Epoch: 33/1000. Train set: Average loss: 0.0900
# Epoch: 33/1000. Validation set: Average loss: 0.0554
# Epoch: 34/1000. Train set: Average loss: 0.0962
# Epoch: 34/1000. Validation set: Average loss: 0.0563
# Epoch: 35/1000. Train set: Average loss: 0.0922
# Epoch: 35/1000. Validation set: Average loss: 0.0550
# Epoch: 36/1000. Train set: Average loss: 0.0938
# Epoch: 36/1000. Validation set: Average loss: 0.0572
# Epoch: 37/1000. Train set: Average loss: 0.0866
# Epoch: 37/1000. Validation set: Average loss: 0.0591
# Epoch: 38/1000. Train set: Average loss: 0.0923
# Epoch: 38/1000. Validation set: Average loss: 0.0591
# Epoch: 39/1000. Train set: Average loss: 0.0924
# Epoch: 39/1000. Validation set: Average loss: 0.0580
# ---Epoch: 39/1000. Train set: Distance ROC: 0.9835	Cosine similarity ROC: 0.9831
# ---Epoch: 39/1000. Validation set: Distance ROC: 0.9012	Cosine similarity ROC: 0.9038
# Epoch: 40/1000. Train set: Average loss: 0.0915
# Epoch: 40/1000. Validation set: Average loss: 0.0549
# Epoch: 41/1000. Train set: Average loss: 0.0950
# Epoch: 41/1000. Validation set: Average loss: 0.0552
# Epoch: 42/1000. Train set: Average loss: 0.0851
# Epoch: 42/1000. Validation set: Average loss: 0.0574
# Epoch: 43/1000. Train set: Average loss: 0.0858
# Epoch: 43/1000. Validation set: Average loss: 0.0553
# Epoch: 44/1000. Train set: Average loss: 0.0785
# Epoch: 44/1000. Validation set: Average loss: 0.0539
# Epoch: 45/1000. Train set: Average loss: 0.0762
# Epoch: 45/1000. Validation set: Average loss: 0.0579
# Epoch: 46/1000. Train set: Average loss: 0.0814
# Epoch: 46/1000. Validation set: Average loss: 0.0527
# Epoch: 47/1000. Train set: Average loss: 0.0796
# Epoch: 47/1000. Validation set: Average loss: 0.0563
# Epoch: 48/1000. Train set: Average loss: 0.0824
# Epoch: 48/1000. Validation set: Average loss: 0.0486
# Epoch: 49/1000. Train set: Average loss: 0.0832
# Epoch: 49/1000. Validation set: Average loss: 0.0528
# ---Epoch: 49/1000. Train set: Distance ROC: 0.9910	Cosine similarity ROC: 0.9899
# ---Epoch: 49/1000. Validation set: Distance ROC: 0.9090	Cosine similarity ROC: 0.9145
# Epoch: 50/1000. Train set: Average loss: 0.0815
# Epoch: 50/1000. Validation set: Average loss: 0.0547
# Epoch: 51/1000. Train set: Average loss: 0.0834
# Epoch: 51/1000. Validation set: Average loss: 0.0574
# Epoch: 52/1000. Train set: Average loss: 0.0792
# Epoch: 52/1000. Validation set: Average loss: 0.0584
# Epoch: 53/1000. Train set: Average loss: 0.0795
# Epoch: 53/1000. Validation set: Average loss: 0.0506
# Epoch: 54/1000. Train set: Average loss: 0.0794
# Epoch: 54/1000. Validation set: Average loss: 0.0517
# Epoch: 55/1000. Train set: Average loss: 0.0719
# Epoch: 55/1000. Validation set: Average loss: 0.0494
# Epoch: 56/1000. Train set: Average loss: 0.0798
# Epoch: 56/1000. Validation set: Average loss: 0.0541
# Epoch: 57/1000. Train set: Average loss: 0.0751
# Epoch: 57/1000. Validation set: Average loss: 0.0519
# Epoch: 58/1000. Train set: Average loss: 0.0723
# Epoch: 58/1000. Validation set: Average loss: 0.0508
# Epoch: 59/1000. Train set: Average loss: 0.0717
# Epoch: 59/1000. Validation set: Average loss: 0.0462
# ---Epoch: 59/1000. Train set: Distance ROC: 0.9974	Cosine similarity ROC: 0.9960
# ---Epoch: 59/1000. Validation set: Distance ROC: 0.9315	Cosine similarity ROC: 0.9274
# Epoch: 60/1000. Train set: Average loss: 0.0693
# Epoch: 60/1000. Validation set: Average loss: 0.0501
# Epoch: 61/1000. Train set: Average loss: 0.0679
# Epoch: 61/1000. Validation set: Average loss: 0.0449
# Epoch: 62/1000. Train set: Average loss: 0.0643
# Epoch: 62/1000. Validation set: Average loss: 0.0464
# Epoch: 63/1000. Train set: Average loss: 0.0685
# Epoch: 63/1000. Validation set: Average loss: 0.0448
# Epoch: 64/1000. Train set: Average loss: 0.0700
# Epoch: 64/1000. Validation set: Average loss: 0.0428
# Epoch: 65/1000. Train set: Average loss: 0.0667
# Epoch: 65/1000. Validation set: Average loss: 0.0450
# Epoch: 66/1000. Train set: Average loss: 0.0685
# Epoch: 66/1000. Validation set: Average loss: 0.0446
# Epoch: 67/1000. Train set: Average loss: 0.0649
# Epoch: 67/1000. Validation set: Average loss: 0.0446
# Epoch: 68/1000. Train set: Average loss: 0.0635
# Epoch: 68/1000. Validation set: Average loss: 0.0400
# Epoch: 69/1000. Train set: Average loss: 0.0644
# Epoch: 69/1000. Validation set: Average loss: 0.0401
# ---Epoch: 69/1000. Train set: Distance ROC: 0.9981	Cosine similarity ROC: 0.9975
# ---Epoch: 69/1000. Validation set: Distance ROC: 0.9358	Cosine similarity ROC: 0.9359
# Epoch: 70/1000. Train set: Average loss: 0.0583
# Epoch: 70/1000. Validation set: Average loss: 0.0434
# Epoch: 71/1000. Train set: Average loss: 0.0620
# Epoch: 71/1000. Validation set: Average loss: 0.0448
# Epoch: 72/1000. Train set: Average loss: 0.0617
# Epoch: 72/1000. Validation set: Average loss: 0.0415
# Epoch: 73/1000. Train set: Average loss: 0.0637
# Epoch: 73/1000. Validation set: Average loss: 0.0411
# Epoch: 74/1000. Train set: Average loss: 0.0594
# Epoch: 74/1000. Validation set: Average loss: 0.0409
# Epoch: 75/1000. Train set: Average loss: 0.0603
# Epoch: 75/1000. Validation set: Average loss: 0.0414
# Epoch: 76/1000. Train set: Average loss: 0.0619
# Epoch: 76/1000. Validation set: Average loss: 0.0419
# Epoch: 77/1000. Train set: Average loss: 0.0588
# Epoch: 77/1000. Validation set: Average loss: 0.0445
# Epoch: 78/1000. Train set: Average loss: 0.0573
# Epoch: 78/1000. Validation set: Average loss: 0.0440
# Epoch: 79/1000. Train set: Average loss: 0.0633
# Epoch: 79/1000. Validation set: Average loss: 0.0426
# ---Epoch: 79/1000. Train set: Distance ROC: 0.9973	Cosine similarity ROC: 0.9967
# ---Epoch: 79/1000. Validation set: Distance ROC: 0.9322	Cosine similarity ROC: 0.9322
# Epoch: 80/1000. Train set: Average loss: 0.0620
# Epoch: 80/1000. Validation set: Average loss: 0.0412
# Epoch: 81/1000. Train set: Average loss: 0.0596
# Epoch: 81/1000. Validation set: Average loss: 0.0403
# Epoch: 82/1000. Train set: Average loss: 0.0585
# Epoch: 82/1000. Validation set: Average loss: 0.0421
# Epoch: 83/1000. Train set: Average loss: 0.0579
# Epoch: 83/1000. Validation set: Average loss: 0.0407
# Epoch: 84/1000. Train set: Average loss: 0.0573
# Epoch: 84/1000. Validation set: Average loss: 0.0421
# Epoch: 85/1000. Train set: Average loss: 0.0603
# Epoch: 85/1000. Validation set: Average loss: 0.0402
# Epoch: 86/1000. Train set: Average loss: 0.0593
# Epoch: 86/1000. Validation set: Average loss: 0.0407
# Epoch: 87/1000. Train set: Average loss: 0.0559
# Epoch: 87/1000. Validation set: Average loss: 0.0393
# Epoch: 88/1000. Train set: Average loss: 0.0604
# Epoch: 88/1000. Validation set: Average loss: 0.0386
# Epoch: 89/1000. Train set: Average loss: 0.0543
# Epoch: 89/1000. Validation set: Average loss: 0.0396
# ---Epoch: 89/1000. Train set: Distance ROC: 0.9985	Cosine similarity ROC: 0.9981
# ---Epoch: 89/1000. Validation set: Distance ROC: 0.9363	Cosine similarity ROC: 0.9336
# Epoch: 90/1000. Train set: Average loss: 0.0589
# Epoch: 90/1000. Validation set: Average loss: 0.0377
# Epoch: 91/1000. Train set: Average loss: 0.0534
# Epoch: 91/1000. Validation set: Average loss: 0.0394
# Epoch: 92/1000. Train set: Average loss: 0.0593
# Epoch: 92/1000. Validation set: Average loss: 0.0405
# Epoch: 93/1000. Train set: Average loss: 0.0618
# Epoch: 93/1000. Validation set: Average loss: 0.0358
# Epoch: 94/1000. Train set: Average loss: 0.0611
# Epoch: 94/1000. Validation set: Average loss: 0.0379
# Epoch: 95/1000. Train set: Average loss: 0.0585
# Epoch: 95/1000. Validation set: Average loss: 0.0390
# Epoch: 96/1000. Train set: Average loss: 0.0554
# Epoch: 96/1000. Validation set: Average loss: 0.0396
# Epoch: 97/1000. Train set: Average loss: 0.0545
# Epoch: 97/1000. Validation set: Average loss: 0.0395
# Epoch: 98/1000. Train set: Average loss: 0.0595
# Epoch: 98/1000. Validation set: Average loss: 0.0393
# Epoch: 99/1000. Train set: Average loss: 0.0576
# Epoch: 99/1000. Validation set: Average loss: 0.0405
# ---Epoch: 99/1000. Train set: Distance ROC: 0.9986	Cosine similarity ROC: 0.9978
# ---Epoch: 99/1000. Validation set: Distance ROC: 0.9343	Cosine similarity ROC: 0.9270
# Epoch: 100/1000. Train set: Average loss: 0.0550
# Epoch: 100/1000. Validation set: Average loss: 0.0394
# Epoch: 101/1000. Train set: Average loss: 0.0610
# Epoch: 101/1000. Validation set: Average loss: 0.0446
# Epoch: 102/1000. Train set: Average loss: 0.0517
# Epoch: 102/1000. Validation set: Average loss: 0.0394
# Epoch: 103/1000. Train set: Average loss: 0.0589
# Epoch: 103/1000. Validation set: Average loss: 0.0434
# Epoch: 104/1000. Train set: Average loss: 0.0590
# Epoch: 104/1000. Validation set: Average loss: 0.0450
# Epoch: 105/1000. Train set: Average loss: 0.0541
# Epoch: 105/1000. Validation set: Average loss: 0.0455
# Epoch: 106/1000. Train set: Average loss: 0.0551
# Epoch: 106/1000. Validation set: Average loss: 0.0436
# Epoch: 107/1000. Train set: Average loss: 0.0594
# Epoch: 107/1000. Validation set: Average loss: 0.0435
# Epoch: 108/1000. Train set: Average loss: 0.0571
# Epoch: 108/1000. Validation set: Average loss: 0.0425
# Epoch: 109/1000. Train set: Average loss: 0.0514
# Epoch: 109/1000. Validation set: Average loss: 0.0410
# ---Epoch: 109/1000. Train set: Distance ROC: 0.9970	Cosine similarity ROC: 0.9965
# ---Epoch: 109/1000. Validation set: Distance ROC: 0.9320	Cosine similarity ROC: 0.9301
# Epoch: 110/1000. Train set: Average loss: 0.0586
# Epoch: 110/1000. Validation set: Average loss: 0.0410
# Epoch: 111/1000. Train set: Average loss: 0.0591
# Epoch: 111/1000. Validation set: Average loss: 0.0384
# Epoch: 112/1000. Train set: Average loss: 0.0556
# Epoch: 112/1000. Validation set: Average loss: 0.0429
# Epoch: 113/1000. Train set: Average loss: 0.0559
# Epoch: 113/1000. Validation set: Average loss: 0.0358
# Epoch: 114/1000. Train set: Average loss: 0.0498
# Epoch: 114/1000. Validation set: Average loss: 0.0413
# Epoch: 115/1000. Train set: Average loss: 0.0567
# Epoch: 115/1000. Validation set: Average loss: 0.0415
# Epoch: 116/1000. Train set: Average loss: 0.0550
# Epoch: 116/1000. Validation set: Average loss: 0.0387
# Epoch: 117/1000. Train set: Average loss: 0.0605
# Epoch: 117/1000. Validation set: Average loss: 0.0387
# Epoch: 118/1000. Train set: Average loss: 0.0539
# Epoch: 118/1000. Validation set: Average loss: 0.0400
# Epoch: 119/1000. Train set: Average loss: 0.0502
# Epoch: 119/1000. Validation set: Average loss: 0.0419
# ---Epoch: 119/1000. Train set: Distance ROC: 0.9985	Cosine similarity ROC: 0.9980
# ---Epoch: 119/1000. Validation set: Distance ROC: 0.9362	Cosine similarity ROC: 0.9331
# Epoch: 120/1000. Train set: Average loss: 0.0565
# Epoch: 120/1000. Validation set: Average loss: 0.0391
# Epoch: 121/1000. Train set: Average loss: 0.0577
# Epoch: 121/1000. Validation set: Average loss: 0.0379
# Epoch: 122/1000. Train set: Average loss: 0.0506
# Epoch: 122/1000. Validation set: Average loss: 0.0427
# Epoch: 123/1000. Train set: Average loss: 0.0485
# Epoch: 123/1000. Validation set: Average loss: 0.0386
# Epoch: 124/1000. Train set: Average loss: 0.0519
# Epoch: 124/1000. Validation set: Average loss: 0.0407
# Epoch: 125/1000. Train set: Average loss: 0.0606
# Epoch: 125/1000. Validation set: Average loss: 0.0399
# Epoch: 126/1000. Train set: Average loss: 0.0591
# Epoch: 126/1000. Validation set: Average loss: 0.0377
# Epoch: 127/1000. Train set: Average loss: 0.0481
# Epoch: 127/1000. Validation set: Average loss: 0.0405
# Epoch: 128/1000. Train set: Average loss: 0.0523
# Epoch: 128/1000. Validation set: Average loss: 0.0388
# Epoch: 129/1000. Train set: Average loss: 0.0521
# Epoch: 129/1000. Validation set: Average loss: 0.0370
# ---Epoch: 129/1000. Train set: Distance ROC: 0.9988	Cosine similarity ROC: 0.9981
# ---Epoch: 129/1000. Validation set: Distance ROC: 0.9369	Cosine similarity ROC: 0.9350
# Epoch: 130/1000. Train set: Average loss: 0.0481
# Epoch: 130/1000. Validation set: Average loss: 0.0371
# Epoch: 131/1000. Train set: Average loss: 0.0505
# Epoch: 131/1000. Validation set: Average loss: 0.0364
# Epoch: 132/1000. Train set: Average loss: 0.0494
# Epoch: 132/1000. Validation set: Average loss: 0.0378
# Epoch: 133/1000. Train set: Average loss: 0.0541
# Epoch: 133/1000. Validation set: Average loss: 0.0372
# Epoch: 134/1000. Train set: Average loss: 0.0515
# Epoch: 134/1000. Validation set: Average loss: 0.0357
# Epoch: 135/1000. Train set: Average loss: 0.0457
# Epoch: 135/1000. Validation set: Average loss: 0.0360
# Epoch: 136/1000. Train set: Average loss: 0.0516
# Epoch: 136/1000. Validation set: Average loss: 0.0345
# Epoch: 137/1000. Train set: Average loss: 0.0512
# Epoch: 137/1000. Validation set: Average loss: 0.0346
# Epoch: 138/1000. Train set: Average loss: 0.0518
# Epoch: 138/1000. Validation set: Average loss: 0.0356
# Epoch: 139/1000. Train set: Average loss: 0.0525
# Epoch: 139/1000. Validation set: Average loss: 0.0359
# ---Epoch: 139/1000. Train set: Distance ROC: 0.9982	Cosine similarity ROC: 0.9977
# ---Epoch: 139/1000. Validation set: Distance ROC: 0.9397	Cosine similarity ROC: 0.9365
# Epoch: 140/1000. Train set: Average loss: 0.0520
# Epoch: 140/1000. Validation set: Average loss: 0.0349
# Epoch: 141/1000. Train set: Average loss: 0.0497
# Epoch: 141/1000. Validation set: Average loss: 0.0361
# Epoch: 142/1000. Train set: Average loss: 0.0497
# Epoch: 142/1000. Validation set: Average loss: 0.0347
# Epoch: 143/1000. Train set: Average loss: 0.0501
# Epoch: 143/1000. Validation set: Average loss: 0.0364
# Epoch: 144/1000. Train set: Average loss: 0.0524
# Epoch: 144/1000. Validation set: Average loss: 0.0348
# Epoch: 145/1000. Train set: Average loss: 0.0541
# Epoch: 145/1000. Validation set: Average loss: 0.0361
# Epoch: 146/1000. Train set: Average loss: 0.0471
# Epoch: 146/1000. Validation set: Average loss: 0.0360
# Epoch: 147/1000. Train set: Average loss: 0.0506
# Epoch: 147/1000. Validation set: Average loss: 0.0370
# Epoch: 148/1000. Train set: Average loss: 0.0480
# Epoch: 148/1000. Validation set: Average loss: 0.0373
# Epoch: 149/1000. Train set: Average loss: 0.0535
# Epoch: 149/1000. Validation set: Average loss: 0.0358
# ---Epoch: 149/1000. Train set: Distance ROC: 0.9987	Cosine similarity ROC: 0.9979
# ---Epoch: 149/1000. Validation set: Distance ROC: 0.9414	Cosine similarity ROC: 0.9400
# Epoch: 150/1000. Train set: Average loss: 0.0546
# Epoch: 150/1000. Validation set: Average loss: 0.0356
# Epoch: 151/1000. Train set: Average loss: 0.0459
# Epoch: 151/1000. Validation set: Average loss: 0.0370
# Epoch: 152/1000. Train set: Average loss: 0.0639
# Epoch: 152/1000. Validation set: Average loss: 0.0391
# Epoch: 153/1000. Train set: Average loss: 0.0515
# Epoch: 153/1000. Validation set: Average loss: 0.0407
# Epoch: 154/1000. Train set: Average loss: 0.0546
# Epoch: 154/1000. Validation set: Average loss: 0.0364
# Epoch: 155/1000. Train set: Average loss: 0.0537
# Epoch: 155/1000. Validation set: Average loss: 0.0378
# Epoch: 156/1000. Train set: Average loss: 0.0536
# Epoch: 156/1000. Validation set: Average loss: 0.0353
# Epoch: 157/1000. Train set: Average loss: 0.0514
# Epoch: 157/1000. Validation set: Average loss: 0.0399
# Epoch: 158/1000. Train set: Average loss: 0.0502
# Epoch: 158/1000. Validation set: Average loss: 0.0402
# Epoch: 159/1000. Train set: Average loss: 0.0515
# Epoch: 159/1000. Validation set: Average loss: 0.0393
# ---Epoch: 159/1000. Train set: Distance ROC: 0.9962	Cosine similarity ROC: 0.9955
# ---Epoch: 159/1000. Validation set: Distance ROC: 0.9309	Cosine similarity ROC: 0.9303
# Epoch: 160/1000. Train set: Average loss: 0.0484
# Epoch: 160/1000. Validation set: Average loss: 0.0429
# Epoch: 161/1000. Train set: Average loss: 0.0525
# Epoch: 161/1000. Validation set: Average loss: 0.0406
# Epoch: 162/1000. Train set: Average loss: 0.0455
# Epoch: 162/1000. Validation set: Average loss: 0.0428
# Epoch: 163/1000. Train set: Average loss: 0.0499
# Epoch: 163/1000. Validation set: Average loss: 0.0403
# Epoch: 164/1000. Train set: Average loss: 0.0545
# Epoch: 164/1000. Validation set: Average loss: 0.0423
# Epoch: 165/1000. Train set: Average loss: 0.0517
# Epoch: 165/1000. Validation set: Average loss: 0.0419
# Epoch: 166/1000. Train set: Average loss: 0.0478
# Epoch: 166/1000. Validation set: Average loss: 0.0407
# Epoch: 167/1000. Train set: Average loss: 0.0523
# Epoch: 167/1000. Validation set: Average loss: 0.0366
# Epoch: 168/1000. Train set: Average loss: 0.0480
# Epoch: 168/1000. Validation set: Average loss: 0.0388
# Epoch: 169/1000. Train set: Average loss: 0.0546
# Epoch: 169/1000. Validation set: Average loss: 0.0378
# ---Epoch: 169/1000. Train set: Distance ROC: 0.9987	Cosine similarity ROC: 0.9982
# ---Epoch: 169/1000. Validation set: Distance ROC: 0.9344	Cosine similarity ROC: 0.9298
# Epoch: 170/1000. Train set: Average loss: 0.0532
# Epoch: 170/1000. Validation set: Average loss: 0.0419
# Epoch: 171/1000. Train set: Average loss: 0.0523
# Epoch: 171/1000. Validation set: Average loss: 0.0423
# Epoch: 172/1000. Train set: Average loss: 0.0460
# Epoch: 172/1000. Validation set: Average loss: 0.0404
# Epoch: 173/1000. Train set: Average loss: 0.0473
# Epoch: 173/1000. Validation set: Average loss: 0.0422
# Epoch: 174/1000. Train set: Average loss: 0.0465
# Epoch: 174/1000. Validation set: Average loss: 0.0421
# Epoch: 175/1000. Train set: Average loss: 0.0551
# Epoch: 175/1000. Validation set: Average loss: 0.0391
# Epoch: 176/1000. Train set: Average loss: 0.0461
# Epoch: 176/1000. Validation set: Average loss: 0.0395
# Epoch: 177/1000. Train set: Average loss: 0.0468
# Epoch: 177/1000. Validation set: Average loss: 0.0369
# Epoch: 178/1000. Train set: Average loss: 0.0482
# Epoch: 178/1000. Validation set: Average loss: 0.0370
# Epoch: 179/1000. Train set: Average loss: 0.0479
# Epoch: 179/1000. Validation set: Average loss: 0.0383
# ---Epoch: 179/1000. Train set: Distance ROC: 0.9984	Cosine similarity ROC: 0.9978
# ---Epoch: 179/1000. Validation set: Distance ROC: 0.9343	Cosine similarity ROC: 0.9306
# Epoch: 180/1000. Train set: Average loss: 0.0463
# Epoch: 180/1000. Validation set: Average loss: 0.0422
# Epoch: 181/1000. Train set: Average loss: 0.0486
# Epoch: 181/1000. Validation set: Average loss: 0.0371
# Epoch: 182/1000. Train set: Average loss: 0.0425
# Epoch: 182/1000. Validation set: Average loss: 0.0353
# Epoch: 183/1000. Train set: Average loss: 0.0469
# Epoch: 183/1000. Validation set: Average loss: 0.0361
# Epoch: 184/1000. Train set: Average loss: 0.0549
# Epoch: 184/1000. Validation set: Average loss: 0.0360
# Epoch: 185/1000. Train set: Average loss: 0.0469
# Epoch: 185/1000. Validation set: Average loss: 0.0345
# Epoch: 186/1000. Train set: Average loss: 0.0506
# Epoch: 186/1000. Validation set: Average loss: 0.0347
# Epoch: 187/1000. Train set: Average loss: 0.0489
# Epoch: 187/1000. Validation set: Average loss: 0.0358
# Epoch: 188/1000. Train set: Average loss: 0.0490
# Epoch: 188/1000. Validation set: Average loss: 0.0330
# Epoch: 189/1000. Train set: Average loss: 0.0502
# Epoch: 189/1000. Validation set: Average loss: 0.0337
# ---Epoch: 189/1000. Train set: Distance ROC: 0.9991	Cosine similarity ROC: 0.9986
# ---Epoch: 189/1000. Validation set: Distance ROC: 0.9446	Cosine similarity ROC: 0.9426
# Epoch: 190/1000. Train set: Average loss: 0.0441
# Epoch: 190/1000. Validation set: Average loss: 0.0335
# Epoch: 191/1000. Train set: Average loss: 0.0437
# Epoch: 191/1000. Validation set: Average loss: 0.0346
# Epoch: 192/1000. Train set: Average loss: 0.0446
# Epoch: 192/1000. Validation set: Average loss: 0.0354
# Epoch: 193/1000. Train set: Average loss: 0.0442
# Epoch: 193/1000. Validation set: Average loss: 0.0352
# Epoch: 194/1000. Train set: Average loss: 0.0452
# Epoch: 194/1000. Validation set: Average loss: 0.0353
# Epoch: 195/1000. Train set: Average loss: 0.0422
# Epoch: 195/1000. Validation set: Average loss: 0.0348
# Epoch: 196/1000. Train set: Average loss: 0.0476
# Epoch: 196/1000. Validation set: Average loss: 0.0359
# Epoch: 197/1000. Train set: Average loss: 0.0466
# Epoch: 197/1000. Validation set: Average loss: 0.0359
# Epoch: 198/1000. Train set: Average loss: 0.0492
# Epoch: 198/1000. Validation set: Average loss: 0.0353
# Epoch: 199/1000. Train set: Average loss: 0.0465
# Epoch: 199/1000. Validation set: Average loss: 0.0349
# ---Epoch: 199/1000. Train set: Distance ROC: 0.9991	Cosine similarity ROC: 0.9987
# ---Epoch: 199/1000. Validation set: Distance ROC: 0.9404	Cosine similarity ROC: 0.9381
# Epoch: 200/1000. Train set: Average loss: 0.0447
# Epoch: 200/1000. Validation set: Average loss: 0.0365
# Epoch: 201/1000. Train set: Average loss: 0.0488
# Epoch: 201/1000. Validation set: Average loss: 0.0396
# Epoch: 202/1000. Train set: Average loss: 0.0449
# Epoch: 202/1000. Validation set: Average loss: 0.0417
# Epoch: 203/1000. Train set: Average loss: 0.0517
# Epoch: 203/1000. Validation set: Average loss: 0.0415
# Epoch: 204/1000. Train set: Average loss: 0.0484
# Epoch: 204/1000. Validation set: Average loss: 0.0391
# Epoch: 205/1000. Train set: Average loss: 0.0480
# Epoch: 205/1000. Validation set: Average loss: 0.0450
# Epoch: 206/1000. Train set: Average loss: 0.0499
# Epoch: 206/1000. Validation set: Average loss: 0.0399
# Epoch: 207/1000. Train set: Average loss: 0.0500
# Epoch: 207/1000. Validation set: Average loss: 0.0365
# Epoch: 208/1000. Train set: Average loss: 0.0490
# Epoch: 208/1000. Validation set: Average loss: 0.0381
# Epoch: 209/1000. Train set: Average loss: 0.0484
# Epoch: 209/1000. Validation set: Average loss: 0.0495
# ---Epoch: 209/1000. Train set: Distance ROC: 0.9948	Cosine similarity ROC: 0.9934
# ---Epoch: 209/1000. Validation set: Distance ROC: 0.9216	Cosine similarity ROC: 0.9174
# Epoch: 210/1000. Train set: Average loss: 0.0485
# Epoch: 210/1000. Validation set: Average loss: 0.0414
# Epoch: 211/1000. Train set: Average loss: 0.0541
# Epoch: 211/1000. Validation set: Average loss: 0.0412
# Epoch: 212/1000. Train set: Average loss: 0.0481
# Epoch: 212/1000. Validation set: Average loss: 0.0399
# Epoch: 213/1000. Train set: Average loss: 0.0494
# Epoch: 213/1000. Validation set: Average loss: 0.0366
# Epoch: 214/1000. Train set: Average loss: 0.0515
# Epoch: 214/1000. Validation set: Average loss: 0.0441
# Epoch: 215/1000. Train set: Average loss: 0.0546
# Epoch: 215/1000. Validation set: Average loss: 0.0386
# Epoch: 216/1000. Train set: Average loss: 0.0479
# Epoch: 216/1000. Validation set: Average loss: 0.0371
# Epoch: 217/1000. Train set: Average loss: 0.0448
# Epoch: 217/1000. Validation set: Average loss: 0.0389
# Epoch: 218/1000. Train set: Average loss: 0.0502
# Epoch: 218/1000. Validation set: Average loss: 0.0367
# Epoch: 219/1000. Train set: Average loss: 0.0475
# Epoch: 219/1000. Validation set: Average loss: 0.0425
# ---Epoch: 219/1000. Train set: Distance ROC: 0.9983	Cosine similarity ROC: 0.9975
# ---Epoch: 219/1000. Validation set: Distance ROC: 0.9407	Cosine similarity ROC: 0.9380
# Epoch: 220/1000. Train set: Average loss: 0.0467
# Epoch: 220/1000. Validation set: Average loss: 0.0393
# Epoch: 221/1000. Train set: Average loss: 0.0486
# Epoch: 221/1000. Validation set: Average loss: 0.0363
# Epoch: 222/1000. Train set: Average loss: 0.0486
# Epoch: 222/1000. Validation set: Average loss: 0.0388
# Epoch: 223/1000. Train set: Average loss: 0.0456
# Epoch: 223/1000. Validation set: Average loss: 0.0401
# Epoch: 224/1000. Train set: Average loss: 0.0438
# Epoch: 224/1000. Validation set: Average loss: 0.0458
# Epoch: 225/1000. Train set: Average loss: 0.0512
# Epoch: 225/1000. Validation set: Average loss: 0.0471
# Epoch: 226/1000. Train set: Average loss: 0.0412
# Epoch: 226/1000. Validation set: Average loss: 0.0445
# Epoch: 227/1000. Train set: Average loss: 0.0467
# Epoch: 227/1000. Validation set: Average loss: 0.0457
# Epoch: 228/1000. Train set: Average loss: 0.0475
# Epoch: 228/1000. Validation set: Average loss: 0.0422
# Epoch: 229/1000. Train set: Average loss: 0.0437
# Epoch: 229/1000. Validation set: Average loss: 0.0406
# ---Epoch: 229/1000. Train set: Distance ROC: 0.9990	Cosine similarity ROC: 0.9987
# ---Epoch: 229/1000. Validation set: Distance ROC: 0.9413	Cosine similarity ROC: 0.9379
# Epoch: 230/1000. Train set: Average loss: 0.0446
# Epoch: 230/1000. Validation set: Average loss: 0.0416
# Epoch: 231/1000. Train set: Average loss: 0.0413
# Epoch: 231/1000. Validation set: Average loss: 0.0412
# Epoch: 232/1000. Train set: Average loss: 0.0437
# Epoch: 232/1000. Validation set: Average loss: 0.0387
# Epoch: 233/1000. Train set: Average loss: 0.0426
# Epoch: 233/1000. Validation set: Average loss: 0.0404
# Epoch: 234/1000. Train set: Average loss: 0.0462
# Epoch: 234/1000. Validation set: Average loss: 0.0414
# Epoch: 235/1000. Train set: Average loss: 0.0431
# Epoch: 235/1000. Validation set: Average loss: 0.0395
# Epoch: 236/1000. Train set: Average loss: 0.0473
# Epoch: 236/1000. Validation set: Average loss: 0.0394
# Epoch: 237/1000. Train set: Average loss: 0.0512
# Epoch: 237/1000. Validation set: Average loss: 0.0423
# Epoch: 238/1000. Train set: Average loss: 0.0495
# Epoch: 238/1000. Validation set: Average loss: 0.0431
# Epoch: 239/1000. Train set: Average loss: 0.0463
# Epoch: 239/1000. Validation set: Average loss: 0.0396
# ---Epoch: 239/1000. Train set: Distance ROC: 0.9989	Cosine similarity ROC: 0.9988
# ---Epoch: 239/1000. Validation set: Distance ROC: 0.9437	Cosine similarity ROC: 0.9426
# Epoch: 240/1000. Train set: Average loss: 0.0476
# Epoch: 240/1000. Validation set: Average loss: 0.0404
# Epoch: 241/1000. Train set: Average loss: 0.0411
# Epoch: 241/1000. Validation set: Average loss: 0.0383
# Epoch: 242/1000. Train set: Average loss: 0.0437
# Epoch: 242/1000. Validation set: Average loss: 0.0393
# Epoch: 243/1000. Train set: Average loss: 0.0431
# Epoch: 243/1000. Validation set: Average loss: 0.0371
# Epoch: 244/1000. Train set: Average loss: 0.0442
# Epoch: 244/1000. Validation set: Average loss: 0.0361
# Epoch: 245/1000. Train set: Average loss: 0.0488
# Epoch: 245/1000. Validation set: Average loss: 0.0386
# Epoch: 246/1000. Train set: Average loss: 0.0457
# Epoch: 246/1000. Validation set: Average loss: 0.0384
# Epoch: 247/1000. Train set: Average loss: 0.0437
# Epoch: 247/1000. Validation set: Average loss: 0.0380
# Epoch: 248/1000. Train set: Average loss: 0.0497
# Epoch: 248/1000. Validation set: Average loss: 0.0416
# Epoch: 249/1000. Train set: Average loss: 0.0460
# Epoch: 249/1000. Validation set: Average loss: 0.0403
# ---Epoch: 249/1000. Train set: Distance ROC: 0.9994	Cosine similarity ROC: 0.9989
# ---Epoch: 249/1000. Validation set: Distance ROC: 0.9401	Cosine similarity ROC: 0.9356
# Epoch: 250/1000. Train set: Average loss: 0.0419
# Epoch: 250/1000. Validation set: Average loss: 0.0378
# Epoch: 251/1000. Train set: Average loss: 0.0494
# Epoch: 251/1000. Validation set: Average loss: 0.0391
# Epoch: 252/1000. Train set: Average loss: 0.0492
# Epoch: 252/1000. Validation set: Average loss: 0.0397
# Epoch: 253/1000. Train set: Average loss: 0.0425
# Epoch: 253/1000. Validation set: Average loss: 0.0375
# Epoch: 254/1000. Train set: Average loss: 0.0444
# Epoch: 254/1000. Validation set: Average loss: 0.0404
# Epoch: 255/1000. Train set: Average loss: 0.0476
# Epoch: 255/1000. Validation set: Average loss: 0.0364
# Epoch: 256/1000. Train set: Average loss: 0.0461
# Epoch: 256/1000. Validation set: Average loss: 0.0380
# Epoch: 257/1000. Train set: Average loss: 0.0449
# Epoch: 257/1000. Validation set: Average loss: 0.0434
# Epoch: 258/1000. Train set: Average loss: 0.0427
# Epoch: 258/1000. Validation set: Average loss: 0.0403
# Epoch: 259/1000. Train set: Average loss: 0.0477
# Epoch: 259/1000. Validation set: Average loss: 0.0361
# ---Epoch: 259/1000. Train set: Distance ROC: 0.9980	Cosine similarity ROC: 0.9975
# ---Epoch: 259/1000. Validation set: Distance ROC: 0.9414	Cosine similarity ROC: 0.9404
# Epoch: 260/1000. Train set: Average loss: 0.0481
# Epoch: 260/1000. Validation set: Average loss: 0.0378
# Epoch: 261/1000. Train set: Average loss: 0.0486
# Epoch: 261/1000. Validation set: Average loss: 0.0368
# Epoch: 262/1000. Train set: Average loss: 0.0443
# Epoch: 262/1000. Validation set: Average loss: 0.0402
# Epoch: 263/1000. Train set: Average loss: 0.0476
# Epoch: 263/1000. Validation set: Average loss: 0.0361
# Epoch: 264/1000. Train set: Average loss: 0.0413
# Epoch: 264/1000. Validation set: Average loss: 0.0365
# Epoch: 265/1000. Train set: Average loss: 0.0438
# Epoch: 265/1000. Validation set: Average loss: 0.0400
# Epoch: 266/1000. Train set: Average loss: 0.0461
# Epoch: 266/1000. Validation set: Average loss: 0.0396
# Epoch: 267/1000. Train set: Average loss: 0.0396
# Epoch: 267/1000. Validation set: Average loss: 0.0366
# Epoch: 268/1000. Train set: Average loss: 0.0456
# Epoch: 268/1000. Validation set: Average loss: 0.0324
# Epoch: 269/1000. Train set: Average loss: 0.0505
# Epoch: 269/1000. Validation set: Average loss: 0.0353
# ---Epoch: 269/1000. Train set: Distance ROC: 0.9988	Cosine similarity ROC: 0.9984
# ---Epoch: 269/1000. Validation set: Distance ROC: 0.9438	Cosine similarity ROC: 0.9450
# Epoch: 270/1000. Train set: Average loss: 0.0432
# Epoch: 270/1000. Validation set: Average loss: 0.0372
# Epoch: 271/1000. Train set: Average loss: 0.0409
# Epoch: 271/1000. Validation set: Average loss: 0.0367
# Epoch: 272/1000. Train set: Average loss: 0.0446
# Epoch: 272/1000. Validation set: Average loss: 0.0349
# Epoch: 273/1000. Train set: Average loss: 0.0481
# Epoch: 273/1000. Validation set: Average loss: 0.0332
# Epoch: 274/1000. Train set: Average loss: 0.0441
# Epoch: 274/1000. Validation set: Average loss: 0.0335
# Epoch: 275/1000. Train set: Average loss: 0.0445
# Epoch: 275/1000. Validation set: Average loss: 0.0354
# Epoch: 276/1000. Train set: Average loss: 0.0492
# Epoch: 276/1000. Validation set: Average loss: 0.0361
# Epoch: 277/1000. Train set: Average loss: 0.0457
# Epoch: 277/1000. Validation set: Average loss: 0.0362
# Epoch: 278/1000. Train set: Average loss: 0.0427
# Epoch: 278/1000. Validation set: Average loss: 0.0370
# Epoch: 279/1000. Train set: Average loss: 0.0436
# Epoch: 279/1000. Validation set: Average loss: 0.0374
# ---Epoch: 279/1000. Train set: Distance ROC: 0.9987	Cosine similarity ROC: 0.9982
# ---Epoch: 279/1000. Validation set: Distance ROC: 0.9435	Cosine similarity ROC: 0.9386
# Epoch: 280/1000. Train set: Average loss: 0.0483
# Epoch: 280/1000. Validation set: Average loss: 0.0359
# Epoch: 281/1000. Train set: Average loss: 0.0412
# Epoch: 281/1000. Validation set: Average loss: 0.0376
# Epoch: 282/1000. Train set: Average loss: 0.0435
# Epoch: 282/1000. Validation set: Average loss: 0.0359
# Epoch: 283/1000. Train set: Average loss: 0.0433
# Epoch: 283/1000. Validation set: Average loss: 0.0369
# Epoch: 284/1000. Train set: Average loss: 0.0423
# Epoch: 284/1000. Validation set: Average loss: 0.0380
# Epoch: 285/1000. Train set: Average loss: 0.0411
# Epoch: 285/1000. Validation set: Average loss: 0.0338
# Epoch: 286/1000. Train set: Average loss: 0.0481
# Epoch: 286/1000. Validation set: Average loss: 0.0345
# Epoch: 287/1000. Train set: Average loss: 0.0429
# Epoch: 287/1000. Validation set: Average loss: 0.0346
# Epoch: 288/1000. Train set: Average loss: 0.0476
# Epoch: 288/1000. Validation set: Average loss: 0.0379
# Epoch: 289/1000. Train set: Average loss: 0.0406
# Epoch: 289/1000. Validation set: Average loss: 0.0388
# ---Epoch: 289/1000. Train set: Distance ROC: 0.9990	Cosine similarity ROC: 0.9987
# ---Epoch: 289/1000. Validation set: Distance ROC: 0.9418	Cosine similarity ROC: 0.9388
# Epoch: 290/1000. Train set: Average loss: 0.0416
# Epoch: 290/1000. Validation set: Average loss: 0.0368
# Epoch: 291/1000. Train set: Average loss: 0.0437
# Epoch: 291/1000. Validation set: Average loss: 0.0397
# Epoch: 292/1000. Train set: Average loss: 0.0460
# Epoch: 292/1000. Validation set: Average loss: 0.0371
# Epoch: 293/1000. Train set: Average loss: 0.0401
# Epoch: 293/1000. Validation set: Average loss: 0.0369
# Epoch: 294/1000. Train set: Average loss: 0.0396
# Epoch: 294/1000. Validation set: Average loss: 0.0373
# Epoch: 295/1000. Train set: Average loss: 0.0410
# Epoch: 295/1000. Validation set: Average loss: 0.0364
# Epoch: 296/1000. Train set: Average loss: 0.0415
# Epoch: 296/1000. Validation set: Average loss: 0.0359
# Epoch: 297/1000. Train set: Average loss: 0.0408
# Epoch: 297/1000. Validation set: Average loss: 0.0372
# Epoch: 298/1000. Train set: Average loss: 0.0437
# Epoch: 298/1000. Validation set: Average loss: 0.0351
# Epoch: 299/1000. Train set: Average loss: 0.0434
# Epoch: 299/1000. Validation set: Average loss: 0.0353
# ---Epoch: 299/1000. Train set: Distance ROC: 0.9991	Cosine similarity ROC: 0.9987
# ---Epoch: 299/1000. Validation set: Distance ROC: 0.9463	Cosine similarity ROC: 0.9455
# Epoch: 300/1000. Train set: Average loss: 0.0422
# Epoch: 300/1000. Validation set: Average loss: 0.0374
# Epoch: 301/1000. Train set: Average loss: 0.0461
# Epoch: 301/1000. Validation set: Average loss: 0.0395
# Epoch: 302/1000. Train set: Average loss: 0.0468
# Epoch: 302/1000. Validation set: Average loss: 0.0407
# Epoch: 303/1000. Train set: Average loss: 0.0431
# Epoch: 303/1000. Validation set: Average loss: 0.0433
# Epoch: 304/1000. Train set: Average loss: 0.0457
# Epoch: 304/1000. Validation set: Average loss: 0.0425
# Epoch: 305/1000. Train set: Average loss: 0.0371
# Epoch: 305/1000. Validation set: Average loss: 0.0433
# Epoch: 306/1000. Train set: Average loss: 0.0427
# Epoch: 306/1000. Validation set: Average loss: 0.0416
# Epoch: 307/1000. Train set: Average loss: 0.0478
# Epoch: 307/1000. Validation set: Average loss: 0.0429
# Epoch: 308/1000. Train set: Average loss: 0.0421
# Epoch: 308/1000. Validation set: Average loss: 0.0395
# Epoch: 309/1000. Train set: Average loss: 0.0507
# Epoch: 309/1000. Validation set: Average loss: 0.0361
# ---Epoch: 309/1000. Train set: Distance ROC: 0.9981	Cosine similarity ROC: 0.9973
# ---Epoch: 309/1000. Validation set: Distance ROC: 0.9398	Cosine similarity ROC: 0.9381
# Epoch: 310/1000. Train set: Average loss: 0.0475
# Epoch: 310/1000. Validation set: Average loss: 0.0345
# Epoch: 311/1000. Train set: Average loss: 0.0415
# Epoch: 311/1000. Validation set: Average loss: 0.0375
# Epoch: 312/1000. Train set: Average loss: 0.0468
# Epoch: 312/1000. Validation set: Average loss: 0.0344
# Epoch: 313/1000. Train set: Average loss: 0.0470
# Epoch: 313/1000. Validation set: Average loss: 0.0310
# Epoch: 314/1000. Train set: Average loss: 0.0407
# Epoch: 314/1000. Validation set: Average loss: 0.0308
# Epoch: 315/1000. Train set: Average loss: 0.0429
# Epoch: 315/1000. Validation set: Average loss: 0.0312
# Epoch: 316/1000. Train set: Average loss: 0.0444
# Epoch: 316/1000. Validation set: Average loss: 0.0315
# Epoch: 317/1000. Train set: Average loss: 0.0469
# Epoch: 317/1000. Validation set: Average loss: 0.0334
# Epoch: 318/1000. Train set: Average loss: 0.0391
# Epoch: 318/1000. Validation set: Average loss: 0.0337
# Epoch: 319/1000. Train set: Average loss: 0.0460
# Epoch: 319/1000. Validation set: Average loss: 0.0337
# ---Epoch: 319/1000. Train set: Distance ROC: 0.9977	Cosine similarity ROC: 0.9969
# ---Epoch: 319/1000. Validation set: Distance ROC: 0.9449	Cosine similarity ROC: 0.9483
# Epoch: 320/1000. Train set: Average loss: 0.0477
# Epoch: 320/1000. Validation set: Average loss: 0.0319
# Epoch: 321/1000. Train set: Average loss: 0.0442
# Epoch: 321/1000. Validation set: Average loss: 0.0304
# Epoch: 322/1000. Train set: Average loss: 0.0409
# Epoch: 322/1000. Validation set: Average loss: 0.0328
# Epoch: 323/1000. Train set: Average loss: 0.0424
# Epoch: 323/1000. Validation set: Average loss: 0.0343
# Epoch: 324/1000. Train set: Average loss: 0.0464
# Epoch: 324/1000. Validation set: Average loss: 0.0336
# Epoch: 325/1000. Train set: Average loss: 0.0430
# Epoch: 325/1000. Validation set: Average loss: 0.0344
# Epoch: 326/1000. Train set: Average loss: 0.0452
# Epoch: 326/1000. Validation set: Average loss: 0.0320
# Epoch: 327/1000. Train set: Average loss: 0.0403
# Epoch: 327/1000. Validation set: Average loss: 0.0317
# Epoch: 328/1000. Train set: Average loss: 0.0426
# Epoch: 328/1000. Validation set: Average loss: 0.0338
# Epoch: 329/1000. Train set: Average loss: 0.0430
# Epoch: 329/1000. Validation set: Average loss: 0.0356
# ---Epoch: 329/1000. Train set: Distance ROC: 0.9989	Cosine similarity ROC: 0.9983
# ---Epoch: 329/1000. Validation set: Distance ROC: 0.9424	Cosine similarity ROC: 0.9430
# Epoch: 330/1000. Train set: Average loss: 0.0443
# Epoch: 330/1000. Validation set: Average loss: 0.0341
# Epoch: 331/1000. Train set: Average loss: 0.0473
# Epoch: 331/1000. Validation set: Average loss: 0.0331
# Epoch: 332/1000. Train set: Average loss: 0.0442
# Epoch: 332/1000. Validation set: Average loss: 0.0323
# Epoch: 333/1000. Train set: Average loss: 0.0440
# Epoch: 333/1000. Validation set: Average loss: 0.0348
# Epoch: 334/1000. Train set: Average loss: 0.0421
# Epoch: 334/1000. Validation set: Average loss: 0.0334
# Epoch: 335/1000. Train set: Average loss: 0.0436
# Epoch: 335/1000. Validation set: Average loss: 0.0332
# Epoch: 336/1000. Train set: Average loss: 0.0419
# Epoch: 336/1000. Validation set: Average loss: 0.0349
# Epoch: 337/1000. Train set: Average loss: 0.0453
# Epoch: 337/1000. Validation set: Average loss: 0.0323
# Epoch: 338/1000. Train set: Average loss: 0.0397
# Epoch: 338/1000. Validation set: Average loss: 0.0318
# Epoch: 339/1000. Train set: Average loss: 0.0405
# Epoch: 339/1000. Validation set: Average loss: 0.0316
# ---Epoch: 339/1000. Train set: Distance ROC: 0.9989	Cosine similarity ROC: 0.9986
# ---Epoch: 339/1000. Validation set: Distance ROC: 0.9471	Cosine similarity ROC: 0.9471
# Epoch: 340/1000. Train set: Average loss: 0.0440
# Epoch: 340/1000. Validation set: Average loss: 0.0322
# Epoch: 341/1000. Train set: Average loss: 0.0430
# Epoch: 341/1000. Validation set: Average loss: 0.0311
# Epoch: 342/1000. Train set: Average loss: 0.0450
# Epoch: 342/1000. Validation set: Average loss: 0.0313
# Epoch: 343/1000. Train set: Average loss: 0.0376
# Epoch: 343/1000. Validation set: Average loss: 0.0313
# Epoch: 344/1000. Train set: Average loss: 0.0433
# Epoch: 344/1000. Validation set: Average loss: 0.0312
# Epoch: 345/1000. Train set: Average loss: 0.0402
# Epoch: 345/1000. Validation set: Average loss: 0.0321
# Epoch: 346/1000. Train set: Average loss: 0.0412
# Epoch: 346/1000. Validation set: Average loss: 0.0317
# Epoch: 347/1000. Train set: Average loss: 0.0401
# Epoch: 347/1000. Validation set: Average loss: 0.0325
# Epoch: 348/1000. Train set: Average loss: 0.0406
# Epoch: 348/1000. Validation set: Average loss: 0.0328
# Epoch: 349/1000. Train set: Average loss: 0.0425
# Epoch: 349/1000. Validation set: Average loss: 0.0317
# ---Epoch: 349/1000. Train set: Distance ROC: 0.9992	Cosine similarity ROC: 0.9988
# ---Epoch: 349/1000. Validation set: Distance ROC: 0.9463	Cosine similarity ROC: 0.9462
# Epoch: 350/1000. Train set: Average loss: 0.0396
# Epoch: 350/1000. Validation set: Average loss: 0.0345
# Epoch: 351/1000. Train set: Average loss: 0.0375
# Epoch: 351/1000. Validation set: Average loss: 0.0368
# Epoch: 352/1000. Train set: Average loss: 0.0378
# Epoch: 352/1000. Validation set: Average loss: 0.0349
# Epoch: 353/1000. Train set: Average loss: 0.0423
# Epoch: 353/1000. Validation set: Average loss: 0.0360
# Epoch: 354/1000. Train set: Average loss: 0.0418
# Epoch: 354/1000. Validation set: Average loss: 0.0355
# Epoch: 355/1000. Train set: Average loss: 0.0402
# Epoch: 355/1000. Validation set: Average loss: 0.0358
# Epoch: 356/1000. Train set: Average loss: 0.0441
# Epoch: 356/1000. Validation set: Average loss: 0.0315
# Epoch: 357/1000. Train set: Average loss: 0.0482
# Epoch: 357/1000. Validation set: Average loss: 0.0339
# Epoch: 358/1000. Train set: Average loss: 0.0401
# Epoch: 358/1000. Validation set: Average loss: 0.0307
# Epoch: 359/1000. Train set: Average loss: 0.0444
# Epoch: 359/1000. Validation set: Average loss: 0.0323
# ---Epoch: 359/1000. Train set: Distance ROC: 0.9988	Cosine similarity ROC: 0.9983
# ---Epoch: 359/1000. Validation set: Distance ROC: 0.9446	Cosine similarity ROC: 0.9381
# Epoch: 360/1000. Train set: Average loss: 0.0391
# Epoch: 360/1000. Validation set: Average loss: 0.0322
# Epoch: 361/1000. Train set: Average loss: 0.0421
# Epoch: 361/1000. Validation set: Average loss: 0.0362
# Epoch: 362/1000. Train set: Average loss: 0.0424
# Epoch: 362/1000. Validation set: Average loss: 0.0335
# Epoch: 363/1000. Train set: Average loss: 0.0392
# Epoch: 363/1000. Validation set: Average loss: 0.0348
# Epoch: 364/1000. Train set: Average loss: 0.0398
# Epoch: 364/1000. Validation set: Average loss: 0.0317
# Epoch: 365/1000. Train set: Average loss: 0.0386
# Epoch: 365/1000. Validation set: Average loss: 0.0345
# Epoch: 366/1000. Train set: Average loss: 0.0416
# Epoch: 366/1000. Validation set: Average loss: 0.0342
# Epoch: 367/1000. Train set: Average loss: 0.0388
# Epoch: 367/1000. Validation set: Average loss: 0.0328
# Epoch: 368/1000. Train set: Average loss: 0.0423
# Epoch: 368/1000. Validation set: Average loss: 0.0365
# Epoch: 369/1000. Train set: Average loss: 0.0401
# Epoch: 369/1000. Validation set: Average loss: 0.0359
# ---Epoch: 369/1000. Train set: Distance ROC: 0.9989	Cosine similarity ROC: 0.9986
# ---Epoch: 369/1000. Validation set: Distance ROC: 0.9455	Cosine similarity ROC: 0.9430
# Epoch: 370/1000. Train set: Average loss: 0.0435
# Epoch: 370/1000. Validation set: Average loss: 0.0395
# Epoch: 371/1000. Train set: Average loss: 0.0427
# Epoch: 371/1000. Validation set: Average loss: 0.0379
# Epoch: 372/1000. Train set: Average loss: 0.0378
# Epoch: 372/1000. Validation set: Average loss: 0.0372
# Epoch: 373/1000. Train set: Average loss: 0.0366
# Epoch: 373/1000. Validation set: Average loss: 0.0398
# Epoch: 374/1000. Train set: Average loss: 0.0412
# Epoch: 374/1000. Validation set: Average loss: 0.0372
# Epoch: 375/1000. Train set: Average loss: 0.0430
# Epoch: 375/1000. Validation set: Average loss: 0.0388
# Epoch: 376/1000. Train set: Average loss: 0.0404
# Epoch: 376/1000. Validation set: Average loss: 0.0395
# Epoch: 377/1000. Train set: Average loss: 0.0393
# Epoch: 377/1000. Validation set: Average loss: 0.0400
# Epoch: 378/1000. Train set: Average loss: 0.0389
# Epoch: 378/1000. Validation set: Average loss: 0.0407
# Epoch: 379/1000. Train set: Average loss: 0.0342
# Epoch: 379/1000. Validation set: Average loss: 0.0333
# ---Epoch: 379/1000. Train set: Distance ROC: 0.9984	Cosine similarity ROC: 0.9982
# ---Epoch: 379/1000. Validation set: Distance ROC: 0.9461	Cosine similarity ROC: 0.9445
# Epoch: 380/1000. Train set: Average loss: 0.0437
# Epoch: 380/1000. Validation set: Average loss: 0.0361
# Epoch: 381/1000. Train set: Average loss: 0.0401
# Epoch: 381/1000. Validation set: Average loss: 0.0404
# Epoch: 382/1000. Train set: Average loss: 0.0396
# Epoch: 382/1000. Validation set: Average loss: 0.0381
# Epoch: 383/1000. Train set: Average loss: 0.0423
# Epoch: 383/1000. Validation set: Average loss: 0.0380
# Epoch: 384/1000. Train set: Average loss: 0.0368
# Epoch: 384/1000. Validation set: Average loss: 0.0370
# Epoch: 385/1000. Train set: Average loss: 0.0396
# Epoch: 385/1000. Validation set: Average loss: 0.0391
# Epoch: 386/1000. Train set: Average loss: 0.0380
# Epoch: 386/1000. Validation set: Average loss: 0.0395
# Epoch: 387/1000. Train set: Average loss: 0.0378
# Epoch: 387/1000. Validation set: Average loss: 0.0406
# Epoch: 388/1000. Train set: Average loss: 0.0394
# Epoch: 388/1000. Validation set: Average loss: 0.0403
# Epoch: 389/1000. Train set: Average loss: 0.0382
# Epoch: 389/1000. Validation set: Average loss: 0.0362
# ---Epoch: 389/1000. Train set: Distance ROC: 0.9989	Cosine similarity ROC: 0.9987
# ---Epoch: 389/1000. Validation set: Distance ROC: 0.9415	Cosine similarity ROC: 0.9405
# Epoch: 390/1000. Train set: Average loss: 0.0398
# Epoch: 390/1000. Validation set: Average loss: 0.0370
# Epoch: 391/1000. Train set: Average loss: 0.0387
# Epoch: 391/1000. Validation set: Average loss: 0.0338
# Epoch: 392/1000. Train set: Average loss: 0.0380
# Epoch: 392/1000. Validation set: Average loss: 0.0342
# Epoch: 393/1000. Train set: Average loss: 0.0445
# Epoch: 393/1000. Validation set: Average loss: 0.0334
# Epoch: 394/1000. Train set: Average loss: 0.0418
# Epoch: 394/1000. Validation set: Average loss: 0.0345
# Epoch: 395/1000. Train set: Average loss: 0.0449
# Epoch: 395/1000. Validation set: Average loss: 0.0337
# Epoch: 396/1000. Train set: Average loss: 0.0380
# Epoch: 396/1000. Validation set: Average loss: 0.0323
# Epoch: 397/1000. Train set: Average loss: 0.0416
# Epoch: 397/1000. Validation set: Average loss: 0.0358
# Epoch: 398/1000. Train set: Average loss: 0.0424
# Epoch: 398/1000. Validation set: Average loss: 0.0346
# Epoch: 399/1000. Train set: Average loss: 0.0371
# Epoch: 399/1000. Validation set: Average loss: 0.0362
# ---Epoch: 399/1000. Train set: Distance ROC: 0.9989	Cosine similarity ROC: 0.9987
# ---Epoch: 399/1000. Validation set: Distance ROC: 0.9436	Cosine similarity ROC: 0.9427
# Epoch: 400/1000. Train set: Average loss: 0.0405
# Epoch: 400/1000. Validation set: Average loss: 0.0400
# Epoch: 401/1000. Train set: Average loss: 0.0348
# Epoch: 401/1000. Validation set: Average loss: 0.0382
# Epoch: 402/1000. Train set: Average loss: 0.0419
# Epoch: 402/1000. Validation set: Average loss: 0.0399
# Epoch: 403/1000. Train set: Average loss: 0.0415
# ...
# Epoch: 869/1000. Train set: Average loss: 0.0299
# Epoch: 869/1000. Validation set: Average loss: 0.0446
# ---Epoch: 869/1000. Train set: Distance ROC: 0.9987	Cosine similarity ROC: 0.9987
# ---Epoch: 869/1000. Validation set: Distance ROC: 0.9200	Cosine similarity ROC: 0.9214
# Epoch: 870/1000. Train set: Average loss: 0.0364
# Epoch: 870/1000. Validation set: Average loss: 0.0440
# Epoch: 871/1000. Train set: Average loss: 0.0351
# Epoch: 871/1000. Validation set: Average loss: 0.0480
# Epoch: 872/1000. Train set: Average loss: 0.0372
# Epoch: 872/1000. Validation set: Average loss: 0.0491
# Epoch: 873/1000. Train set: Average loss: 0.0351
# Epoch: 873/1000. Validation set: Average loss: 0.0445
# Epoch: 874/1000. Train set: Average loss: 0.0337
# Epoch: 874/1000. Validation set: Average loss: 0.0483
# Epoch: 875/1000. Train set: Average loss: 0.0386
# Epoch: 875/1000. Validation set: Average loss: 0.0495
# Epoch: 876/1000. Train set: Average loss: 0.0328
# Epoch: 876/1000. Validation set: Average loss: 0.0506
# Epoch: 877/1000. Train set: Average loss: 0.0323
# Epoch: 877/1000. Validation set: Average loss: 0.0484
# Epoch: 878/1000. Train set: Average loss: 0.0320
# Epoch: 878/1000. Validation set: Average loss: 0.0468
# Epoch: 879/1000. Train set: Average loss: 0.0356
# Epoch: 879/1000. Validation set: Average loss: 0.0452
# ---Epoch: 879/1000. Train set: Distance ROC: 0.9989	Cosine similarity ROC: 0.9989
# ---Epoch: 879/1000. Validation set: Distance ROC: 0.9242	Cosine similarity ROC: 0.9250
# Epoch: 880/1000. Train set: Average loss: 0.0290
# Epoch: 880/1000. Validation set: Average loss: 0.0456
# Epoch: 881/1000. Train set: Average loss: 0.0387
# Epoch: 881/1000. Validation set: Average loss: 0.0454
# Epoch: 882/1000. Train set: Average loss: 0.0295
# Epoch: 882/1000. Validation set: Average loss: 0.0467
# Epoch: 883/1000. Train set: Average loss: 0.0371
# Epoch: 883/1000. Validation set: Average loss: 0.0474
# Epoch: 884/1000. Train set: Average loss: 0.0344
# Epoch: 884/1000. Validation set: Average loss: 0.0480
# Epoch: 885/1000. Train set: Average loss: 0.0321
# Epoch: 885/1000. Validation set: Average loss: 0.0470
# Epoch: 886/1000. Train set: Average loss: 0.0312
# Epoch: 886/1000. Validation set: Average loss: 0.0495
# Epoch: 887/1000. Train set: Average loss: 0.0331
# Epoch: 887/1000. Validation set: Average loss: 0.0491
# Epoch: 888/1000. Train set: Average loss: 0.0373
# Epoch: 888/1000. Validation set: Average loss: 0.0486
# Epoch: 889/1000. Train set: Average loss: 0.0321
# Epoch: 889/1000. Validation set: Average loss: 0.0486
# ---Epoch: 889/1000. Train set: Distance ROC: 0.9990	Cosine similarity ROC: 0.9991
# ---Epoch: 889/1000. Validation set: Distance ROC: 0.9247	Cosine similarity ROC: 0.9243
# Epoch: 890/1000. Train set: Average loss: 0.0374
# Epoch: 890/1000. Validation set: Average loss: 0.0497
# Epoch: 891/1000. Train set: Average loss: 0.0288
# Epoch: 891/1000. Validation set: Average loss: 0.0455
# Epoch: 892/1000. Train set: Average loss: 0.0335
# Epoch: 892/1000. Validation set: Average loss: 0.0473
# Epoch: 893/1000. Train set: Average loss: 0.0300
# Epoch: 893/1000. Validation set: Average loss: 0.0458
# Epoch: 894/1000. Train set: Average loss: 0.0323
# Epoch: 894/1000. Validation set: Average loss: 0.0468
# Epoch: 895/1000. Train set: Average loss: 0.0292
# Epoch: 895/1000. Validation set: Average loss: 0.0487
# Epoch: 896/1000. Train set: Average loss: 0.0313
# Epoch: 896/1000. Validation set: Average loss: 0.0474
# Epoch: 897/1000. Train set: Average loss: 0.0350
# Epoch: 897/1000. Validation set: Average loss: 0.0498
# Epoch: 898/1000. Train set: Average loss: 0.0339
# Epoch: 898/1000. Validation set: Average loss: 0.0453
# Epoch: 899/1000. Train set: Average loss: 0.0329
# Epoch: 899/1000. Validation set: Average loss: 0.0480
# ---Epoch: 899/1000. Train set: Distance ROC: 0.9991	Cosine similarity ROC: 0.9991
# ---Epoch: 899/1000. Validation set: Distance ROC: 0.9253	Cosine similarity ROC: 0.9257
# Epoch: 900/1000. Train set: Average loss: 0.0342
# Epoch: 900/1000. Validation set: Average loss: 0.0474
# Epoch: 901/1000. Train set: Average loss: 0.0282
# Epoch: 901/1000. Validation set: Average loss: 0.0494
# Epoch: 902/1000. Train set: Average loss: 0.0322
# Epoch: 902/1000. Validation set: Average loss: 0.0486
# Epoch: 903/1000. Train set: Average loss: 0.0355
# Epoch: 903/1000. Validation set: Average loss: 0.0491
# Epoch: 904/1000. Train set: Average loss: 0.0333
# Epoch: 904/1000. Validation set: Average loss: 0.0453
# Epoch: 905/1000. Train set: Average loss: 0.0310
# Epoch: 905/1000. Validation set: Average loss: 0.0447
# Epoch: 906/1000. Train set: Average loss: 0.0320
# Epoch: 906/1000. Validation set: Average loss: 0.0430
# Epoch: 907/1000. Train set: Average loss: 0.0329
# Epoch: 907/1000. Validation set: Average loss: 0.0457
# Epoch: 908/1000. Train set: Average loss: 0.0286
# Epoch: 908/1000. Validation set: Average loss: 0.0450
# Epoch: 909/1000. Train set: Average loss: 0.0345
# Epoch: 909/1000. Validation set: Average loss: 0.0467
# ---Epoch: 909/1000. Train set: Distance ROC: 0.9990	Cosine similarity ROC: 0.9989
# ---Epoch: 909/1000. Validation set: Distance ROC: 0.9295	Cosine similarity ROC: 0.9297
# Epoch: 910/1000. Train set: Average loss: 0.0318
# Epoch: 910/1000. Validation set: Average loss: 0.0444
# Epoch: 911/1000. Train set: Average loss: 0.0301
# Epoch: 911/1000. Validation set: Average loss: 0.0459
# Epoch: 912/1000. Train set: Average loss: 0.0326
# Epoch: 912/1000. Validation set: Average loss: 0.0485
# Epoch: 913/1000. Train set: Average loss: 0.0347
# Epoch: 913/1000. Validation set: Average loss: 0.0473
# Epoch: 914/1000. Train set: Average loss: 0.0295
# Epoch: 914/1000. Validation set: Average loss: 0.0508
# Epoch: 915/1000. Train set: Average loss: 0.0351
# Epoch: 915/1000. Validation set: Average loss: 0.0494
# Epoch: 916/1000. Train set: Average loss: 0.0301
# Epoch: 916/1000. Validation set: Average loss: 0.0499
# Epoch: 917/1000. Train set: Average loss: 0.0360
# Epoch: 917/1000. Validation set: Average loss: 0.0488
# Epoch: 918/1000. Train set: Average loss: 0.0324
# Epoch: 918/1000. Validation set: Average loss: 0.0463
# Epoch: 919/1000. Train set: Average loss: 0.0303
# Epoch: 919/1000. Validation set: Average loss: 0.0455
# ---Epoch: 919/1000. Train set: Distance ROC: 0.9990	Cosine similarity ROC: 0.9990
# ---Epoch: 919/1000. Validation set: Distance ROC: 0.9279	Cosine similarity ROC: 0.9278
# Epoch: 920/1000. Train set: Average loss: 0.0362
# Epoch: 920/1000. Validation set: Average loss: 0.0497
# Epoch: 921/1000. Train set: Average loss: 0.0328
# Epoch: 921/1000. Validation set: Average loss: 0.0505
# Epoch: 922/1000. Train set: Average loss: 0.0360
# Epoch: 922/1000. Validation set: Average loss: 0.0508
# Epoch: 923/1000. Train set: Average loss: 0.0298
# Epoch: 923/1000. Validation set: Average loss: 0.0466
# Epoch: 924/1000. Train set: Average loss: 0.0374
# Epoch: 924/1000. Validation set: Average loss: 0.0451
# Epoch: 925/1000. Train set: Average loss: 0.0313
# Epoch: 925/1000. Validation set: Average loss: 0.0467
# Epoch: 926/1000. Train set: Average loss: 0.0324
# Epoch: 926/1000. Validation set: Average loss: 0.0451
# Epoch: 927/1000. Train set: Average loss: 0.0328
# Epoch: 927/1000. Validation set: Average loss: 0.0486
# Epoch: 928/1000. Train set: Average loss: 0.0298
# Epoch: 928/1000. Validation set: Average loss: 0.0472
# Epoch: 929/1000. Train set: Average loss: 0.0330
# Epoch: 929/1000. Validation set: Average loss: 0.0483
# ---Epoch: 929/1000. Train set: Distance ROC: 0.9988	Cosine similarity ROC: 0.9989
# ---Epoch: 929/1000. Validation set: Distance ROC: 0.9266	Cosine similarity ROC: 0.9273
# Epoch: 930/1000. Train set: Average loss: 0.0329
# Epoch: 930/1000. Validation set: Average loss: 0.0501
# Epoch: 931/1000. Train set: Average loss: 0.0285
# Epoch: 931/1000. Validation set: Average loss: 0.0449
# Epoch: 932/1000. Train set: Average loss: 0.0326
# Epoch: 932/1000. Validation set: Average loss: 0.0463
# Epoch: 933/1000. Train set: Average loss: 0.0293
# Epoch: 933/1000. Validation set: Average loss: 0.0497
# Epoch: 934/1000. Train set: Average loss: 0.0288
# Epoch: 934/1000. Validation set: Average loss: 0.0428
# Epoch: 935/1000. Train set: Average loss: 0.0329
# Epoch: 935/1000. Validation set: Average loss: 0.0467
# Epoch: 936/1000. Train set: Average loss: 0.0356
# Epoch: 936/1000. Validation set: Average loss: 0.0456
# Epoch: 937/1000. Train set: Average loss: 0.0345
# Epoch: 937/1000. Validation set: Average loss: 0.0463
# Epoch: 938/1000. Train set: Average loss: 0.0338
# Epoch: 938/1000. Validation set: Average loss: 0.0485
# Epoch: 939/1000. Train set: Average loss: 0.0284
# Epoch: 939/1000. Validation set: Average loss: 0.0434
# ---Epoch: 939/1000. Train set: Distance ROC: 0.9991	Cosine similarity ROC: 0.9991
# ---Epoch: 939/1000. Validation set: Distance ROC: 0.9321	Cosine similarity ROC: 0.9320
# Epoch: 940/1000. Train set: Average loss: 0.0328
# Epoch: 940/1000. Validation set: Average loss: 0.0469
# Epoch: 941/1000. Train set: Average loss: 0.0303
# Epoch: 941/1000. Validation set: Average loss: 0.0469
# Epoch: 942/1000. Train set: Average loss: 0.0339
# Epoch: 942/1000. Validation set: Average loss: 0.0434
# Epoch: 943/1000. Train set: Average loss: 0.0320
# Epoch: 943/1000. Validation set: Average loss: 0.0427
# Epoch: 944/1000. Train set: Average loss: 0.0313
# Epoch: 944/1000. Validation set: Average loss: 0.0459
# Epoch: 945/1000. Train set: Average loss: 0.0298
# Epoch: 945/1000. Validation set: Average loss: 0.0440
# Epoch: 946/1000. Train set: Average loss: 0.0350
# Epoch: 946/1000. Validation set: Average loss: 0.0474
# Epoch: 947/1000. Train set: Average loss: 0.0311
# Epoch: 947/1000. Validation set: Average loss: 0.0441
# Epoch: 948/1000. Train set: Average loss: 0.0280
# Epoch: 948/1000. Validation set: Average loss: 0.0444
# Epoch: 949/1000. Train set: Average loss: 0.0304
# Epoch: 949/1000. Validation set: Average loss: 0.0470
# ---Epoch: 949/1000. Train set: Distance ROC: 0.9991	Cosine similarity ROC: 0.9990
# ---Epoch: 949/1000. Validation set: Distance ROC: 0.9305	Cosine similarity ROC: 0.9304
# Epoch: 950/1000. Train set: Average loss: 0.0285
# Epoch: 950/1000. Validation set: Average loss: 0.0441
# Epoch: 951/1000. Train set: Average loss: 0.0303
# Epoch: 951/1000. Validation set: Average loss: 0.0396
# Epoch: 952/1000. Train set: Average loss: 0.0306
# Epoch: 952/1000. Validation set: Average loss: 0.0456
# Epoch: 953/1000. Train set: Average loss: 0.0349
# Epoch: 953/1000. Validation set: Average loss: 0.0395
# Epoch: 954/1000. Train set: Average loss: 0.0288
# Epoch: 954/1000. Validation set: Average loss: 0.0372
# Epoch: 955/1000. Train set: Average loss: 0.0338
# Epoch: 955/1000. Validation set: Average loss: 0.0406
# Epoch: 956/1000. Train set: Average loss: 0.0314
# Epoch: 956/1000. Validation set: Average loss: 0.0389
# Epoch: 957/1000. Train set: Average loss: 0.0350
# Epoch: 957/1000. Validation set: Average loss: 0.0397
# Epoch: 958/1000. Train set: Average loss: 0.0355
# Epoch: 958/1000. Validation set: Average loss: 0.0410
# Epoch: 959/1000. Train set: Average loss: 0.0328
# Epoch: 959/1000. Validation set: Average loss: 0.0371
# ---Epoch: 959/1000. Train set: Distance ROC: 0.9989	Cosine similarity ROC: 0.9988
# ---Epoch: 959/1000. Validation set: Distance ROC: 0.9414	Cosine similarity ROC: 0.9412
# Epoch: 960/1000. Train set: Average loss: 0.0321
# Epoch: 960/1000. Validation set: Average loss: 0.0390
# Epoch: 961/1000. Train set: Average loss: 0.0325
# Epoch: 961/1000. Validation set: Average loss: 0.0393
# Epoch: 962/1000. Train set: Average loss: 0.0296
# Epoch: 962/1000. Validation set: Average loss: 0.0423
# Epoch: 963/1000. Train set: Average loss: 0.0319
# Epoch: 963/1000. Validation set: Average loss: 0.0394
# Epoch: 964/1000. Train set: Average loss: 0.0339
# Epoch: 964/1000. Validation set: Average loss: 0.0420
# Epoch: 965/1000. Train set: Average loss: 0.0334
# Epoch: 965/1000. Validation set: Average loss: 0.0401
# Epoch: 966/1000. Train set: Average loss: 0.0354
# Epoch: 966/1000. Validation set: Average loss: 0.0422
# Epoch: 967/1000. Train set: Average loss: 0.0369
# Epoch: 967/1000. Validation set: Average loss: 0.0437
# Epoch: 968/1000. Train set: Average loss: 0.0340
# Epoch: 968/1000. Validation set: Average loss: 0.0375
# Epoch: 969/1000. Train set: Average loss: 0.0325
# Epoch: 969/1000. Validation set: Average loss: 0.0362
# ---Epoch: 969/1000. Train set: Distance ROC: 0.9986	Cosine similarity ROC: 0.9987
# ---Epoch: 969/1000. Validation set: Distance ROC: 0.9426	Cosine similarity ROC: 0.9433
# Epoch: 970/1000. Train set: Average loss: 0.0312
# Epoch: 970/1000. Validation set: Average loss: 0.0400
# Epoch: 971/1000. Train set: Average loss: 0.0335
# Epoch: 971/1000. Validation set: Average loss: 0.0368
# Epoch: 972/1000. Train set: Average loss: 0.0322
# Epoch: 972/1000. Validation set: Average loss: 0.0419
# Epoch: 973/1000. Train set: Average loss: 0.0328
# Epoch: 973/1000. Validation set: Average loss: 0.0399
# Epoch: 974/1000. Train set: Average loss: 0.0311
# Epoch: 974/1000. Validation set: Average loss: 0.0426
# Epoch: 975/1000. Train set: Average loss: 0.0326
# Epoch: 975/1000. Validation set: Average loss: 0.0455
# Epoch: 976/1000. Train set: Average loss: 0.0326
# Epoch: 976/1000. Validation set: Average loss: 0.0445
# Epoch: 977/1000. Train set: Average loss: 0.0323
# Epoch: 977/1000. Validation set: Average loss: 0.0436
# Epoch: 978/1000. Train set: Average loss: 0.0344
# Epoch: 978/1000. Validation set: Average loss: 0.0454
# Epoch: 979/1000. Train set: Average loss: 0.0337
# Epoch: 979/1000. Validation set: Average loss: 0.0408
# ---Epoch: 979/1000. Train set: Distance ROC: 0.9993	Cosine similarity ROC: 0.9992
# ---Epoch: 979/1000. Validation set: Distance ROC: 0.9381	Cosine similarity ROC: 0.9383
# Epoch: 980/1000. Train set: Average loss: 0.0306
# Epoch: 980/1000. Validation set: Average loss: 0.0466
# Epoch: 981/1000. Train set: Average loss: 0.0309
# Epoch: 981/1000. Validation set: Average loss: 0.0438
# Epoch: 982/1000. Train set: Average loss: 0.0345
# Epoch: 982/1000. Validation set: Average loss: 0.0450
# Epoch: 983/1000. Train set: Average loss: 0.0316
# Epoch: 983/1000. Validation set: Average loss: 0.0494
# Epoch: 984/1000. Train set: Average loss: 0.0338
# Epoch: 984/1000. Validation set: Average loss: 0.0517
# Epoch: 985/1000. Train set: Average loss: 0.0306
# Epoch: 985/1000. Validation set: Average loss: 0.0462
# Epoch: 986/1000. Train set: Average loss: 0.0303
# Epoch: 986/1000. Validation set: Average loss: 0.0473
# Epoch: 987/1000. Train set: Average loss: 0.0314
# Epoch: 987/1000. Validation set: Average loss: 0.0465
# Epoch: 988/1000. Train set: Average loss: 0.0331
# Epoch: 988/1000. Validation set: Average loss: 0.0503
# Epoch: 989/1000. Train set: Average loss: 0.0293
# Epoch: 989/1000. Validation set: Average loss: 0.0492
# ---Epoch: 989/1000. Train set: Distance ROC: 0.9990	Cosine similarity ROC: 0.9989
# ---Epoch: 989/1000. Validation set: Distance ROC: 0.9304	Cosine similarity ROC: 0.9290
# Epoch: 990/1000. Train set: Average loss: 0.0288
# Epoch: 990/1000. Validation set: Average loss: 0.0474
# Epoch: 991/1000. Train set: Average loss: 0.0276
# Epoch: 991/1000. Validation set: Average loss: 0.0455
# Epoch: 992/1000. Train set: Average loss: 0.0322
# Epoch: 992/1000. Validation set: Average loss: 0.0464
# Epoch: 993/1000. Train set: Average loss: 0.0383
# Epoch: 993/1000. Validation set: Average loss: 0.0453
# Epoch: 994/1000. Train set: Average loss: 0.0331
# Epoch: 994/1000. Validation set: Average loss: 0.0472
# Epoch: 995/1000. Train set: Average loss: 0.0331
# Epoch: 995/1000. Validation set: Average loss: 0.0445
# Epoch: 996/1000. Train set: Average loss: 0.0335
# Epoch: 996/1000. Validation set: Average loss: 0.0448
# Epoch: 997/1000. Train set: Average loss: 0.0284
# Epoch: 997/1000. Validation set: Average loss: 0.0439
# Epoch: 998/1000. Train set: Average loss: 0.0330
# Epoch: 998/1000. Validation set: Average loss: 0.0448
# Epoch: 999/1000. Train set: Average loss: 0.0305
# Epoch: 999/1000. Validation set: Average loss: 0.0455
# ---Epoch: 999/1000. Train set: Distance ROC: 0.9993	Cosine similarity ROC: 0.9993
# ---Epoch: 999/1000. Validation set: Distance ROC: 0.9320	Cosine similarity ROC: 0.9328
# Epoch: 1000/1000. Train set: Average loss: 0.0344
# Epoch: 1000/1000. Validation set: Average loss: 0.0466
# 25946.719697237015
